# %% [markdown]
# ### HR Analytics Feature Importances

# %% [markdown]
# #### Set source path to import code

# %%
# %pwd
# Out:
# 'C:\\Users\\t0272m1\\Projects\\HR Analytics'

# %%
source_path = 'E:\HR-Analytics\source'
source_path
# Out:
# 'E:\\HR-Analytics\\source'

# %%
import os
os.chdir(source_path)
# %pwd
# Out:
# 'E:\\HR-Analytics\\source'

# %%
ls
# Out:
#  Volume in drive E is DATA
#  Volume Serial Number is AEFF-63BE
#
#  Directory of E:\HR-Analytics\source
#
# 06/04/2019  02:09 PM    <DIR>          .
# 06/04/2019  02:09 PM    <DIR>          ..
# 05/02/2019  11:01 AM                 2 __init__.py
# 05/16/2019  11:42 AM             8,585 __main__.py
# 06/04/2019  06:24 PM    <DIR>          __pycache__
# 05/31/2019  02:33 PM            16,184 base_table.py
# 06/04/2019  06:26 PM            26,135 calendrical.py
# 06/04/2019  02:22 PM             2,210 config_jnap.yml
# 06/04/2019  02:21 PM            10,380 config_shap.yml
# 06/03/2019  11:21 AM             4,713 config_shap2.yml
# 06/03/2019  11:23 AM             2,210 config_tac.yml
# 05/01/2019  11:07 AM               498 config_wap.yml
# 05/17/2019  09:09 AM             6,131 database.py
# 06/04/2019  02:27 PM             8,585 main.py
# 06/04/2019  06:18 PM            23,878 model.py
# 04/30/2019  03:23 PM             2,842 pipeline.yml
# 05/01/2019  02:09 PM             3,673 pipeline_brap.py
# 05/01/2019  02:08 PM             3,670 pipeline_bvp.py
# 05/22/2019  12:02 PM             9,266 pipeline_jnap.py
# 06/04/2019  12:36 PM            21,152 pipeline_shap.py
# 06/04/2019  02:27 PM            21,133 pipeline_tac.py
# 05/01/2019  02:08 PM             3,619 pipeline_wap.py
# 05/01/2019  02:08 PM             3,673 pipeline_wtap.py
#               20 File(s)        178,539 bytes
#                3 Dir(s)  232,529,584,128 bytes free

# %% [markdown]
# #### Imports

# %%
import calendar
import datetime
import itertools
import jaydebeapi as jdb
import json
import math
import matplotlib
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pandas.io.sql as psql
import psycopg2
import random
import requests
import seaborn as sns
from sklearn.model_selection import train_test_split
from sqlalchemy import create_engine
import statsmodels as sm
from statsmodels.tsa.statespace.sarimax import SARIMAX
import urllib.request

# %%
# Internal Python Packages
import calendrical
from database import connect_greenplum
from database import write_frame_to_pg
from database import create_sqlalchemy_engine
from main import get_pipeline_config
from main import get_plant_config

# %% [markdown]
# #### Get specifications

# %%
pipeline_specs = get_pipeline_config(source_path)
pipeline_specs
# Out:
# {'datalake': {'schema': 'lab_datasci',
#   'host': 'shbdmdwp001.servers.chrysler.com',
#   'port': 5432,
#   'user': 'datasci',
#   'password': 'datasci_01',
#   'database': 'odshawq'},
#  'jdbc': {'driver': 'com.ibm.db2.jcc.DB2Driver',
#   'server': 'jdbc:db2://SRVR1874.dbms.chrysler.com:18740/AUCERPTP',
#   'user': 'datasci',
#   'password': 'datasci_01',
#   'jar_file': 'c:/installed/sqllib/java/db2jcc4.jar'},
#  'holidays': {'calendar_us': ['2016-01-01',
#    '2016-01-18',
#    '2016-03-25',
#    '2016-03-28',
#    '2016-05-30',
#    '2016-07-04',
#    '2016-09-05',
#    '2016-11-08',
#    '2016-11-11',
#    '2016-11-24',
#    '2016-11-25',
#    '2016-12-26',
#    '2016-12-27',
#    '2016-12-28',
#    '2016-12-29',
#    '2016-12-30',
#    '2017-01-02',
#    '2017-01-22',
#    '2017-04-14',
#    '2017-04-17',
#    '2017-05-29',
#    '2017-07-04',
#    '2017-09-04',
#    '2017-11-10',
#    '2017-11-22',
#    '2017-11-23',
#    '2017-12-25',
#    '2017-12-26',
#    '2017-12-29',
#    '2017-12-30',
#    '2017-12-31',
#    '2018-01-01',
#    '2018-01-15',
#    '2018-03-30',
#    '2018-04-02',
#    '2018-05-28',
#    '2018-07-04',
#    '2018-09-03',
#    '2018-11-06',
#    '2018-11-12',
#    '2018-11-22',
#    '2018-11-23',
#    '2018-12-24',
#    '2018-12-25',
#    '2018-12-26',
#    '2018-12-27',
#    '2018-12-28',
#    '2018-12-31',
#    '2019-01-01',
#    '2019-01-21',
#    '2019-04-19',
#    '2019-04-22',
#    '2019-05-27',
#    '2019-07-04',
#    '2019-09-02'],
#   'calendar_canada': ['2016-01-01',
#    '2016-03-25',
#    '2016-03-28',
#    '2016-05-20',
#    '2016-05-23',
#    '2016-07-01',
#    '2016-08-01',
#    '2016-09-02',
#    '2016-09-05',
#    '2016-10-10',
#    '2016-11-11',
#    '2016-12-26',
#    '2016-12-27',
#    '2016-12-28',
#    '2016-12-29',
#    '2016-12-30',
#    '2017-01-02',
#    '2017-04-14',
#    '2017-04-17',
#    '2017-05-19',
#    '2017-05-22',
#    '2017-06-30',
#    '2017-09-01',
#    '2017-09-04',
#    '2017-10-09',
#    '2017-11-10',
#    '2017-12-25',
#    '2017-12-26',
#    '2017-12-27',
#    '2017-12-28',
#    '2017-12-29',
#    '2018-01-01',
#    '2018-03-30',
#    '2018-04-02',
#    '2018-05-18',
#    '2018-05-21',
#    '2018-07-02',
#    '2018-08-31',
#    '2018-09-03',
#    '2018-10-08',
#    '2018-11-12',
#    '2018-12-24',
#    '2018-12-25',
#    '2018-12-26',
#    '2018-12-27',
#    '2018-12-28',
#    '2018-12-31',
#    '2019-01-01']}}

# %%
plant_id = 'jnap'
plant_id
# Out:
# 'jnap'

# %%
pipeline_specs['plant_id'] = plant_id
pipeline_specs['project_directory'] = source_path

# %%
plant_specs = get_plant_config(pipeline_specs)
plant_specs
# Out:
# {'plant': {'code': 4012,
#   'shift_days': 4,
#   'shift_hours': 10,
#   'absence_codes': ['BERC',
#    'BERE',
#    'BERU',
#    'BERX',
#    'CARE',
#    'CARU',
#    'FMLA',
#    'FMLD',
#    'FMLU',
#    'HOMD',
#    'ILFE',
#    'ILFU',
#    'IPBE',
#    'IPME',
#    'IPNU',
#    'IPSE',
#    'JURE',
#    'MISE',
#    'MISU',
#    'PERU',
#    'PPAA',
#    'PPAU',
#    'TRAG',
#    'WTRU']},
#  'base_table': {'start_date': datetime.date(2018, 1, 1),
#   'end_date': None,
#   'write_table': True},
#  'model': {'target': 'absences_unplanned',
#   'prediction_date': datetime.date(2019, 6, 9),
#   'npreds': 4,
#   'p_arima': 1,
#   'd_arima': 0,
#   'q_arima': 0,
#   'top_features': 5,
#   'band_pct': 0.3,
#   'levels': ['crew', 'production_line'],
#   'crews': ['A', 'B', 'C'],
#   'departments': {'Material': '3300',
#    'Body Shop': '3310',
#    'Paint Shop': '3330',
#    'Trim': '9150',
#    'Chassis': '9170',
#    'Final': '9173',
#    'Quality 1': '9190',
#    'Quality 2': '9193'},
#   'production_lines': {'Material': 'Material',
#    'Body Shop': 'Body Shop',
#    'Paint Shop': 'Paint Shop',
#    'Trim 1': 'Trim',
#    'Trim 2': 'Trim',
#    'Door Line': 'Trim',
#    'Engine Line': 'Chassis',
#    'Chassis 1 & 2': 'Chassis',
#    'Sunroof Deck': 'Chassis',
#    'Chassis 3': 'Chassis',
#    'Chassis 4': 'Chassis',
#    'Final 1': 'Final',
#    'Final 2': 'Final',
#    'Rolls': 'Final',
#    'Quality 1': 'Quality 1',
#    'Quality 2': 'Quality 2'},
#   'write_table': True}}

# %% [markdown]
# #### Holiday Calendar

# %%
chrysler_holiday_table = pipeline_specs['holidays']['calendar_us']
chrysler_holiday_table
# Out:
# ['2016-01-01',
#  '2016-01-18',
#  '2016-03-25',
#  '2016-03-28',
#  '2016-05-30',
#  '2016-07-04',
#  '2016-09-05',
#  '2016-11-08',
#  '2016-11-11',
#  '2016-11-24',
#  '2016-11-25',
#  '2016-12-26',
#  '2016-12-27',
#  '2016-12-28',
#  '2016-12-29',
#  '2016-12-30',
#  '2017-01-02',
#  '2017-01-22',
#  '2017-04-14',
#  '2017-04-17',
#  '2017-05-29',
#  '2017-07-04',
#  '2017-09-04',
#  '2017-11-10',
#  '2017-11-22',
#  '2017-11-23',
#  '2017-12-25',
#  '2017-12-26',
#  '2017-12-29',
#  '2017-12-30',
#  '2017-12-31',
#  '2018-01-01',
#  '2018-01-15',
#  '2018-03-30',
#  '2018-04-02',
#  '2018-05-28',
#  '2018-07-04',
#  '2018-09-03',
#  '2018-11-06',
#  '2018-11-12',
#  '2018-11-22',
#  '2018-11-23',
#  '2018-12-24',
#  '2018-12-25',
#  '2018-12-26',
#  '2018-12-27',
#  '2018-12-28',
#  '2018-12-31',
#  '2019-01-01',
#  '2019-01-21',
#  '2019-04-19',
#  '2019-04-22',
#  '2019-05-27',
#  '2019-07-04',
#  '2019-09-02']

# %% [markdown]
# #### Read in prediction table

# %%
data_path = 'E:/HR-Analytics/data'
data_path
# Out:
# 'E:/HR-Analytics/data'

# %%
# input_file is a sequenced model file
file_name = '.'.join(['abs_jnap_plant_20190609_tbl', 'csv'])
file_path = '/'.join([data_path, file_name])
dfp = pd.read_csv(file_path)

# %%
dfp.columns
# Out:
# Index(['crew', 'model_feature1', 'model_feature2', 'model_feature3',
#        'model_feature4', 'model_feature5', 'predicted', 'predicted_high',
#        'predicted_low', 'production_line', 'workdate', 'group_total_cid',
#        'lost_hours', 'actual_hours', 'paa_hours', 'absences_unplanned',
#        'absences_late', 'absences_noshow', 'absences_any', 'mean_absence_pct',
#        'mean_experience', 'absences_planned', 'home_canvasses',
#        'absences_fmla', 'peia_count', 'tpt_count', 'streak_1', 'streak_2',
#        'streak_3', 'streak_4_plus', 'cluster', 'group_total', 'tpt_unplanned',
#        'tpt_extra', 'absences_unplanned_rolling_sum_5',
#        'absences_unplanned_rolling_median_5',
#        'absences_unplanned_rolling_sum_12',
#        'absences_unplanned_rolling_median_12',
#        'absences_unplanned_rolling_sum_20',
#        'absences_unplanned_rolling_median_20', 'actual_hours_rolling_mean_20',
#        'actual_hours_rolling_median_20', 'lost_hours_rolling_mean_20',
#        'lost_hours_rolling_median_20', 'kp_residual_5', 'kp_residual_12',
#        'kp_residual_20', 'year', 'quarter', 'month', 'week', 'day',
#        'day_of_week', 'day_of_year', 'nth_kday', 'next_day_delta', 'actual',
#        'au_crew_mean', 'au_dow_mean', 'au_week_mean', 'au_month_mean',
#        'au_nth_kday_mean', 'holiday', 'holiday_offset', 'holiday_dates',
#        'au_holiday_mean', 'au_dow_pct', 'au_week_pct', 'au_month_pct',
#        'au_nth_kday_pct', 'au_holiday_pct', 'day_name', 'month_name',
#        'feature1', 'feature2', 'feature3', 'feature4', 'feature5', 'dept_name',
#        'dept'],
#       dtype='object')

# %%
dfp.drop(columns=['dept', 'dept_name'], inplace=True)

# %%
dfp.shape
# Out:
# (9961, 11)

# %%
dfp.sample(50)
# Out:
#      crew                       model_feature1  \
# 1476    A  absences_unplanned_rolling_median_5
# 742     C                           peia_count
# 429     B                              cluster
# 6481    C                              cluster
# 3763    A  absences_unplanned_rolling_median_5
# 8480    B                          day_of_year
# 9698    C                         actual_hours
# 8298    A                            paa_hours
# 34      B                            paa_hours
# 207     B                         absences_any
# 2324    C                             streak_3
# 1942    A                           peia_count
# 3529    B                         absences_any
# 6530    B                                month
# 3170    B                                 week
# 4833    C                         absences_any
# 6928    C                             nth_kday
# 4227    A                        streak_4_plus
# 6599    A                             streak_3
# 881     A  absences_unplanned_rolling_median_5
# 8214    C  absences_unplanned_rolling_median_5
# 6102    A                           peia_count
# 2859    B                       next_day_delta
# 6546    C                          group_total
# 2891    B                         absences_any
# 6122    A                           peia_count
# 9496    B                          day_of_week
# 961     B                                month
# 7306    B                                month
# 2886    B                                month
# 3738    C                          group_total
# 2940    C                             streak_3
# 145     C                       kp_residual_12
# 6115    C                              cluster
# 5534    C                        kp_residual_5
# 8353    B                            tpt_extra
# 2772    B                              cluster
# 3429    C                           peia_count
# 4518    A                           peia_count
# 1407    C                              cluster
# 2620    A  absences_unplanned_rolling_median_5
# 4432    A                                 year
# 6411    A         lost_hours_rolling_median_20
# 8488    B    absences_unplanned_rolling_sum_20
# 1669    C                           peia_count
# 8646    C                        absences_late
# 8116    A                            tpt_count
# 2604    A                           peia_count
# 784     C                             streak_3
# 2211    B                              cluster
#
#                            model_feature2  \
# 1476     absences_unplanned_rolling_sum_5
# 742          actual_hours_rolling_mean_20
# 429                          absences_any
# 6481                         absences_any
# 3763         lost_hours_rolling_median_20
# 8480                      absences_noshow
# 9698                           lost_hours
# 8298                          day_of_year
# 34                                cluster
# 207                        home_canvasses
# 2324                       next_day_delta
# 1942  absences_unplanned_rolling_median_5
# 3529                       home_canvasses
# 6530                                  day
# 3170                          day_of_week
# 4833                       home_canvasses
# 6928                                month
# 4227                          group_total
# 6599                       next_day_delta
# 881          lost_hours_rolling_median_20
# 8214                          day_of_week
# 6102                       kp_residual_12
# 2859                             streak_3
# 6546                        absences_fmla
# 2891                       home_canvasses
# 6122  absences_unplanned_rolling_median_5
# 9496                           lost_hours
# 961                                   day
# 7306    absences_unplanned_rolling_sum_20
# 2886                                  day
# 3738                        absences_fmla
# 2940                       next_day_delta
# 145                               quarter
# 6115                     mean_absence_pct
# 5534                       next_day_delta
# 8353                             nth_kday
# 2772                         absences_any
# 3429                          group_total
# 4518                       kp_residual_12
# 1407                     mean_absence_pct
# 2620     absences_unplanned_rolling_sum_5
# 4432                          day_of_year
# 6411                             streak_2
# 8488                           lost_hours
# 1669                          group_total
# 8646                          group_total
# 8116                                 year
# 2604                       kp_residual_12
# 784                        next_day_delta
# 2211                         absences_any
#
#                             model_feature3  \
# 1476     absences_unplanned_rolling_sum_12
# 742      absences_unplanned_rolling_sum_20
# 429                               streak_2
# 6481                              streak_3
# 3763                      mean_absence_pct
# 8480        actual_hours_rolling_median_20
# 9698                                   day
# 8298                        kp_residual_20
# 34                         mean_experience
# 207                               streak_2
# 2324                               cluster
# 1942      absences_unplanned_rolling_sum_5
# 3529                              streak_2
# 6530                               quarter
# 3170                           day_of_year
# 4833                           group_total
# 6928                                  year
# 4227                               cluster
# 6599                              streak_2
# 881                       mean_absence_pct
# 8214                          absences_any
# 6102                         absences_fmla
# 2859                          absences_any
# 6546                             paa_hours
# 2891                              streak_2
# 6122      absences_unplanned_rolling_sum_5
# 9496                          actual_hours
# 961                                quarter
# 7306                         absences_fmla
# 2886                               quarter
# 3738                             paa_hours
# 2940                               cluster
# 145                            day_of_year
# 6115                          absences_any
# 5534     absences_unplanned_rolling_sum_20
# 8353                        kp_residual_20
# 2772                              streak_2
# 3429                        home_canvasses
# 4518                         absences_fmla
# 1407                          absences_any
# 2620     absences_unplanned_rolling_sum_12
# 4432                                  week
# 6411                      mean_absence_pct
# 8488        actual_hours_rolling_median_20
# 1669                        home_canvasses
# 8646                         tpt_unplanned
# 8116  absences_unplanned_rolling_median_12
# 2604                         absences_fmla
# 784                                cluster
# 2211                              streak_2
#
#                             model_feature4  \
# 1476     absences_unplanned_rolling_sum_20
# 742         actual_hours_rolling_median_20
# 429                               streak_3
# 6481                           group_total
# 3763                               quarter
# 8480                        next_day_delta
# 9698                                 month
# 8298                       mean_experience
# 34       absences_unplanned_rolling_sum_12
# 207                               streak_1
# 2324                          absences_any
# 1942                               cluster
# 3529                              streak_1
# 6530  absences_unplanned_rolling_median_12
# 3170                       mean_experience
# 4833                             paa_hours
# 6928   absences_unplanned_rolling_median_5
# 4227                          absences_any
# 6599  absences_unplanned_rolling_median_20
# 881                                quarter
# 8214  absences_unplanned_rolling_median_20
# 6102                           group_total
# 2859                                  year
# 6546     absences_unplanned_rolling_sum_20
# 2891                              streak_1
# 6122                               cluster
# 9496                                  week
# 961   absences_unplanned_rolling_median_12
# 7306                             paa_hours
# 2886  absences_unplanned_rolling_median_12
# 3738     absences_unplanned_rolling_sum_20
# 2940                          absences_any
# 145                        mean_experience
# 6115                                 month
# 5534  absences_unplanned_rolling_median_20
# 8353                               cluster
# 2772                              streak_3
# 3429                          absences_any
# 4518                           group_total
# 1407                                 month
# 2620     absences_unplanned_rolling_sum_20
# 4432                             paa_hours
# 6411  absences_unplanned_rolling_median_20
# 8488          lost_hours_rolling_median_20
# 1669                          absences_any
# 8646          lost_hours_rolling_median_20
# 8116   absences_unplanned_rolling_median_5
# 2604                           group_total
# 784                           absences_any
# 2211                              streak_3
#
#                             model_feature5  predicted  predicted_high  \
# 1476                        next_day_delta        4.0               5
# 742                         next_day_delta        8.0              10
# 429                            group_total        5.0               6
# 6481                        home_canvasses        2.0               3
# 3763      absences_unplanned_rolling_sum_5        2.0               3
# 8480                          actual_hours        4.0               5
# 9698                                  week       14.0              18
# 8298                        home_canvasses       12.0              16
# 34    absences_unplanned_rolling_median_12        1.0               1
# 207                            group_total        6.0               8
# 2324                      mean_absence_pct        8.0              10
# 1942                              streak_3        3.0               4
# 3529                           group_total        9.0              12
# 6530                             paa_hours        2.0               3
# 3170                                  year        5.0               6
# 4833                        next_day_delta        7.0               9
# 6928        actual_hours_rolling_median_20        9.0              12
# 4227                        home_canvasses        5.0               6
# 6599                         absences_fmla        2.0               3
# 881       absences_unplanned_rolling_sum_5        6.0               8
# 8214     absences_unplanned_rolling_sum_20        9.0              12
# 6102                            lost_hours        3.0               4
# 2859                              streak_2        5.0               6
# 6546                          absences_any        5.0               6
# 2891                           group_total       10.0              13
# 6122                              streak_3        4.0               5
# 9496                           day_of_year       11.0              14
# 961                              paa_hours        6.0               8
# 7306                              streak_1        7.0               9
# 2886                             paa_hours        7.0               9
# 3738                          absences_any       11.0              14
# 2940                      mean_absence_pct        7.0               9
# 145                            day_of_week        7.0               9
# 6115                           group_total        8.0              10
# 5534            lost_hours_rolling_mean_20        7.0               9
# 8353                      mean_absence_pct       12.0              16
# 2772                           group_total        8.0              10
# 3429   absences_unplanned_rolling_median_5        3.0               4
# 4518                            lost_hours        3.0               4
# 1407                           group_total        6.0               8
# 2620                        next_day_delta        6.0               8
# 4432                                 month        6.0               8
# 6411                               cluster        9.0              12
# 8488                       absences_noshow        8.0              10
# 1669   absences_unplanned_rolling_median_5        3.0               4
# 8646  absences_unplanned_rolling_median_12        0.0               0
# 8116        actual_hours_rolling_median_20       11.0              14
# 2604                            lost_hours        3.0               4
# 784                       mean_absence_pct        7.0               9
# 2211                           group_total        6.0               8
#
#       predicted_low production_line  ... au_holiday_pct   day_name  \
# 1476              3       Chassis 4  ...            -11   Thursday
# 742               6         Final 1  ...             54   Saturday
# 429               4   Chassis 1 & 2  ...             25   Thursday
# 6481              1           Rolls  ...           -100   Saturday
# 3763              1       Chassis 3  ...            -12   Thursday
# 8480              3       Chassis 4  ...            -14   Thursday
# 9698             10        Material  ...              1   Saturday
# 8298              8   Chassis 1 & 2  ...              0  Wednesday
# 34                1       Chassis 3  ...            -60  Wednesday
# 207               4          Trim 1  ...            -13     Friday
# 2324              6       Door Line  ...              2    Tuesday
# 1942              2         Final 2  ...             17  Wednesday
# 3529              6          Trim 1  ...             17     Friday
# 6530              1     Engine Line  ...            -62     Friday
# 3170              4       Chassis 4  ...             19   Saturday
# 4833              5     Engine Line  ...             -9     Friday
# 6928              6          Trim 1  ...            -28     Friday
# 4227              4       Door Line  ...              6     Monday
# 6599              1           Rolls  ...             29    Tuesday
# 881               4       Chassis 3  ...             27     Monday
# 8214              6   Chassis 1 & 2  ...            -27     Friday
# 6102              2    Sunroof Deck  ...             41     Monday
# 2859              4          Trim 2  ...             26  Wednesday
# 6546              4          Trim 1  ...            -71     Friday
# 2891              7          Trim 1  ...             41     Friday
# 6122              3         Final 2  ...             51    Tuesday
# 9496              8          Trim 1  ...             67   Saturday
# 961               4     Engine Line  ...            -23   Thursday
# 7306              5     Engine Line  ...             12  Wednesday
# 2886              5     Engine Line  ...             41     Friday
# 3738              8          Trim 1  ...            -27    Tuesday
# 2940              5       Door Line  ...              9     Monday
# 145               5       Chassis 4  ...            -20    Tuesday
# 6115              6          Trim 2  ...             10     Monday
# 5534              5       Chassis 3  ...             -4     Monday
# 8353              8        Material  ...              5     Friday
# 2772              6   Chassis 1 & 2  ...             67   Saturday
# 3429              2    Sunroof Deck  ...            -19   Saturday
# 4518              2    Sunroof Deck  ...             -6  Wednesday
# 1407              4          Trim 2  ...            -22   Saturday
# 2620              4       Chassis 4  ...             12   Thursday
# 4432              4          Trim 2  ...            -34   Thursday
# 6411              6          Trim 1  ...            -16  Wednesday
# 8488              6          Trim 1  ...            -14   Thursday
# 1669              2    Sunroof Deck  ...            -12    Tuesday
# 8646              0   Chassis 1 & 2  ...             -4   Saturday
# 8116              8          Trim 1  ...             30     Monday
# 2604              2    Sunroof Deck  ...             27  Wednesday
# 784               5       Door Line  ...            -13    Tuesday
# 2211              4   Chassis 1 & 2  ...              4  Wednesday
#
#       month_name        feature1        feature2        feature3  \
# 1476       March   Thursday: -5%   Week 12: -16%     March: -12%
# 742     February   Saturday: -2%     Week 6: 18%    February: 0%
# 429      January  Thursday: -11%    Week 4: -17%   January: -23%
# 6481    December   Saturday: -2%  Week 52: -100%   December: -4%
# 3763        July   Thursday: -5%     Week 30: 1%        July: 6%
# 8480       April  Thursday: -11%    Week 15: -4%      April: -5%
# 9698        June   Saturday: -2%   Week 23: -13%        June: 5%
# 8298       April  Wednesday: -9%   Week 14: -11%     April: -11%
# 34       January   Wednesday: 4%    Week 1: -60%   January: -23%
# 207      January      Friday: 4%    Week 2: -34%   January: -23%
# 2324         May     Tuesday: 9%    Week 19: 31%        May: 24%
# 1942       April  Wednesday: -9%   Week 16: -18%     April: -11%
# 3529        July      Friday: 4%     Week 28: 7%        July: 4%
# 6530     January      Friday: 4%    Week 1: -60%   January: -23%
# 3170        June    Saturday: 3%    Week 25: 12%       June: 17%
# 4833   September     Friday: -6%   Week 38: -19%  September: -6%
# 6928     January     Friday: -6%    Week 4: -20%   January: -16%
# 4227      August     Monday: 24%   Week 34: -10%     August: -5%
# 6599     January    Tuesday: -7%    Week 2: -10%   January: -15%
# 881     February     Monday: 24%     Week 8: -7%   February: -2%
# 8214       March     Friday: -6%    Week 13: -8%       March: 0%
# 6102    December     Monday: 24%    Week 49: 26%   December: 11%
# 2859        June   Wednesday: 4%    Week 23: 24%       June: 17%
# 6546     January     Friday: -6%    Week 1: -54%   January: -16%
# 2891        June      Friday: 4%    Week 23: 24%       June: 17%
# 6122    December    Tuesday: -7%    Week 49: 26%   December: 11%
# 9496        June    Saturday: 3%    Week 22: 35%       June: 17%
# 961     February  Thursday: -11%     Week 8: -2%    February: 0%
# 7306    February   Wednesday: 4%      Week 7: 0%    February: 0%
# 2886        June      Friday: 4%    Week 23: 24%       June: 17%
# 3738        July     Tuesday: 9%   Week 30: -24%       July: -2%
# 2940        June      Monday: 0%     Week 24: 6%        June: 5%
# 145      January     Tuesday: 9%    Week 2: -15%   January: -16%
# 6115    December      Monday: 0%     Week 49: 8%   December: -4%
# 5534     October      Monday: 0%    Week 44: -7%   October: -10%
# 8353       April      Friday: 4%    Week 14: -6%      April: -5%
# 2772        June    Saturday: 3%    Week 22: 35%       June: 17%
# 3429        July   Saturday: -2%    Week 27: -7%       July: -2%
# 4518   September  Wednesday: -9%     Week 36: 3%   September: 3%
# 1407       March   Saturday: -2%     Week 11: 7%       March: 0%
# 2620         May   Thursday: -5%     Week 21: 9%        May: 20%
# 4432      August   Thursday: -5%   Week 35: -16%     August: -5%
# 6411    December  Wednesday: -9%     Week 51: 0%   December: 11%
# 8488       April  Thursday: -11%    Week 15: -4%      April: -5%
# 1669       April     Tuesday: 9%    Week 14: 13%       April: 3%
# 8646       April   Saturday: -2%    Week 16: -5%       April: 3%
# 8116       March     Monday: 24%   Week 13: -21%     March: -12%
# 2604         May  Wednesday: -9%     Week 21: 9%        May: 20%
# 784     February     Tuesday: 9%     Week 7: -5%    February: 0%
# 2211         May   Wednesday: 4%    Week 18: 21%        May: 29%
#
#                  feature4                               feature5  dept_name  \
# 1476   4th Thursday: -10%   5 days after St. Patrick's Day: -11%    Chassis
# 742      2nd Saturday: 7%     4 days before Valentine's Day: 54%      Final
# 429    4th Thursday: -15%             10 days after MLK Day: 25%    Chassis
# 6481   5th Saturday: -10%    3 days before New Year's Day: -100%      Final
# 3763   4th Thursday: -10%   22 days after Independence Day: -12%    Chassis
# 8480   2nd Thursday: -14%        8 days before Good Friday: -14%    Chassis
# 9698     2nd Saturday: 7%         8 days before Father's Day: 1%   Material
# 8298   1st Wednesday: -6%         16 days before Good Friday: 0%    Chassis
# 34     1st Wednesday: -2%      2 days after New Year's Day: -60%    Chassis
# 207       2nd Friday: 12%            3 days before MLK Day: -13%       Trim
# 2324     2nd Tuesday: 11%         3 days after Cinco de Mayo: 2%       Trim
# 1942  3rd Wednesday: -16%              17 days after Easter: 17%      Final
# 3529      2nd Friday: 12%     9 days after Independence Day: 17%       Trim
# 6530       1st Friday: 2%      3 days after New Year's Day: -62%    Chassis
# 3170     4th Saturday: 2%         6 days after Father's Day: 19%    Chassis
# 4833     3rd Friday: -13%           18 days after Labor Day: -9%    Chassis
# 6928      4th Friday: -8%             4 days after MLK Day: -28%       Trim
# 4227      3rd Monday: 29%           14 days before Labor Day: 6%       Trim
# 6599     2nd Tuesday: -2%       7 days after New Year's Day: 29%      Final
# 881       3rd Monday: 29%       0 days it's President's Day: 27%    Chassis
# 8214      5th Friday: 18%  12 days after St. Patrick's Day: -27%    Chassis
# 6102      1st Monday: 25%        11 days after Thanksgiving: 41%    Chassis
# 2859   1st Wednesday: -2%         9 days after Memorial Day: 26%       Trim
# 6546      1st Friday: -9%      3 days after New Year's Day: -71%       Trim
# 2891      2nd Friday: 12%        9 days before Father's Day: 41%       Trim
# 6122      1st Tuesday: 3%        12 days after Thanksgiving: 51%      Final
# 9496     1st Saturday: 7%         5 days after Memorial Day: 67%       Trim
# 961    4th Thursday: -15%     3 days after President's Day: -23%    Chassis
# 7306    2nd Wednesday: 5%     1 days before Valentine's Day: 12%    Chassis
# 2886      2nd Friday: 12%        9 days before Father's Day: 41%    Chassis
# 3738      4th Tuesday: 4%   20 days after Independence Day: -27%       Trim
# 2940       2nd Monday: 4%         6 days before Father's Day: 9%       Trim
# 145      2nd Tuesday: 11%            6 days before MLK Day: -20%    Chassis
# 6115      1st Monday: -6%        11 days after Thanksgiving: 10%       Trim
# 5534       5th Monday: 4%           2 days before Halloween: -4%    Chassis
# 8353       1st Friday: 2%         14 days before Good Friday: 5%   Material
# 2772     1st Saturday: 7%         5 days after Memorial Day: 67%    Chassis
# 3429     1st Saturday: 1%    3 days after Independence Day: -19%    Chassis
# 4518   1st Wednesday: -6%            2 days after Labor Day: -6%    Chassis
# 1407     3rd Saturday: 0%    0 days it's St. Patrick's Day: -22%       Trim
# 2620   4th Thursday: -10%        4 days before Memorial Day: 12%    Chassis
# 4432    5th Thursday: 16%          4 days before Labor Day: -34%       Trim
# 6411  3rd Wednesday: -16%          6 days before Christmas: -16%       Trim
# 8488   2nd Thursday: -14%        8 days before Good Friday: -14%       Trim
# 1669     1st Tuesday: 17%              2 days after Easter: -12%    Chassis
# 8646     3rd Saturday: 0%          1 days after Good Friday: -4%    Chassis
# 8116       4th Monday: 9%    8 days after St. Patrick's Day: 30%       Trim
# 2604  4th Wednesday: -10%        5 days before Memorial Day: 27%    Chassis
# 784      2nd Tuesday: 11%    1 days before Valentine's Day: -13%       Trim
# 2211   1st Wednesday: -2%        3 days before Cinco de Mayo: 4%    Chassis
#
#       dept
# 1476  9170
# 742   9173
# 429   9170
# 6481  9173
# 3763  9170
# 8480  9170
# 9698  3300
# 8298  9170
# 34    9170
# 207   9150
# 2324  9150
# 1942  9173
# 3529  9150
# 6530  9170
# 3170  9170
# 4833  9170
# 6928  9150
# 4227  9150
# 6599  9173
# 881   9170
# 8214  9170
# 6102  9170
# 2859  9150
# 6546  9150
# 2891  9150
# 6122  9173
# 9496  9150
# 961   9170
# 7306  9170
# 2886  9170
# 3738  9150
# 2940  9150
# 145   9170
# 6115  9150
# 5534  9170
# 8353  3300
# 2772  9170
# 3429  9170
# 4518  9170
# 1407  9150
# 2620  9170
# 4432  9150
# 6411  9150
# 8488  9150
# 1669  9170
# 8646  9170
# 8116  9150
# 2604  9170
# 784   9150
# 2211  9170
#
# [50 rows x 80 columns]

# %%
dfp['year'].value_counts()
# Out:
# 2018    6482
# 2019    3503
# Name: year, dtype: int64

# %%
dfp.drop(columns=['feature1', 'feature2', 'feature3', 'feature4', 'feature5'], inplace=True)

# %%
dfp.to_csv(file_path, index=False)

# %% [markdown]
# #### Read in model table

# %%
data_path = 'E:/HR-Analytics/data'
data_path
# Out:
# 'E:/HR-Analytics/data'

# %%
table_date = '20190609'
table_date
# Out:
# '20190609'

# %%
table_name = '_'.join(['abs', plant_id, 'model', table_date, 'tbl'])
table_name
# Out:
# 'abs_jnap_model_20190609_tbl'

# %%
# input_file is a sequenced model file
file_name = '.'.join([table_name, 'csv'])
file_path = '/'.join([data_path, file_name])
dfm = pd.read_csv(file_path)

# %%
dfm.shape
# Out:
# (14287, 48)

# %%
dfm.columns
# Out:
# Index(['workdate', 'crew', 'production_line', 'group_total_cid', 'lost_hours',
#        'actual_hours', 'paa_hours', 'absences_unplanned', 'absences_late',
#        'absences_noshow', 'absences_any', 'mean_absence_pct',
#        'mean_experience', 'absences_planned', 'home_canvasses',
#        'absences_fmla', 'peia_count', 'tpt_count', 'streak_1', 'streak_2',
#        'streak_3', 'streak_4_plus', 'cluster', 'group_total', 'tpt_unplanned',
#        'tpt_extra', 'absences_unplanned_rolling_sum_5',
#        'absences_unplanned_rolling_median_5',
#        'absences_unplanned_rolling_sum_12',
#        'absences_unplanned_rolling_median_12',
#        'absences_unplanned_rolling_sum_20',
#        'absences_unplanned_rolling_median_20', 'actual_hours_rolling_mean_20',
#        'actual_hours_rolling_median_20', 'lost_hours_rolling_mean_20',
#        'lost_hours_rolling_median_20', 'kp_residual_5', 'kp_residual_12',
#        'kp_residual_20', 'year', 'quarter', 'month', 'week', 'day',
#        'day_of_week', 'day_of_year', 'nth_kday', 'next_day_delta'],
#       dtype='object')

# %%
dfm['workdate'].min()
# Out:
# '2018-01-02'

# %%
dfm['workdate'].max()
# Out:
# '2019-06-01'

# %% [markdown]
# #### Historical Calendrical Analysis

# %%
dfm_mean = dfm.groupby(['crew'])[['absences_unplanned']].mean().reset_index()
dfm_mean
# Out:
#   crew  absences_unplanned
# 0    A            4.442304
# 1    B            4.731236
# 2    C            5.935333

# %%
dfm1 = pd.merge(dfm, dfm_mean, left_on=['crew'], right_on=['crew'], how='left')
dfm1.rename(index=str, columns={'absences_unplanned_x': 'absences_unplanned', 'absences_unplanned_y': 'au_crew_mean'}, inplace=True)
dfm1.sample(20)
# Out:
#          workdate crew production_line  group_total_cid  lost_hours  \
# 7434   2018-09-20    B       Door Line             51.0        90.0
# 4515   2018-06-09    C      Paint Shop              2.0         0.0
# 10153  2019-01-07    A    Sunroof Deck              3.0        10.0
# 540    2018-01-20    C           Rolls             24.0        20.0
# 9183   2018-11-24    B       Chassis 3             74.0        21.1
# 11934  2019-03-09    C      Paint Shop              2.0         0.0
# 6046   2018-08-02    B       Quality 1             44.0        40.5
# 493    2018-01-19    C                              6.0         0.0
# 10596  2019-01-23    A          Trim 1            110.0        61.0
# 3701   2018-05-11    C       Quality 2             33.0        60.0
# 5068   2018-06-29    B   Chassis 1 & 2             82.0        61.2
# 2245   2018-03-21    A       Body Shop             24.0        10.0
# 2108   2018-03-16    B                             10.0         0.0
# 12823  2019-04-09    C          Trim 1            112.0       141.2
# 1746   2018-03-03    B       Quality 2             38.0         8.0
# 13863  2019-05-17    C       Body Shop             21.0        20.0
# 11438  2019-02-21    A         Final 1             66.0        30.0
# 6521   2018-08-18    C      Paint Shop              2.0         0.0
# 1925   2018-03-09    C       Chassis 4             57.0        70.0
# 10084  2019-01-04    B       Chassis 4              6.0         0.0
#
#        actual_hours  paa_hours  absences_unplanned  absences_late  \
# 7434          520.8        0.0                   5            0.0
# 4515           22.5        0.0                   0            0.0
# 10153          30.0       10.0                   1            0.0
# 540           242.9        0.0                   3            0.0
# 9183          727.4       20.0                  11            2.0
# 11934          20.5        0.0                   0            0.0
# 6046          413.5       20.0                   1            1.0
# 493            65.5        0.0                   0            0.0
# 10596        1073.6        0.0                  22            0.0
# 3701          317.8       30.0                   4            0.0
# 5068          828.6        0.0                   4            3.0
# 2245          241.2        0.0                   0            0.0
# 2108           96.8        8.0                   1            0.0
# 12823        1099.7        0.0                  25            2.0
# 1746          375.6        0.0                   2            0.0
# 13863         220.4       10.0                   4            0.0
# 11438         601.2        0.0                   9            0.0
# 6521           23.0        0.0                   0            0.0
# 1925          573.7       10.0                   4            0.0
# 10084          57.8        0.0                   0            0.0
#
#        absences_noshow  ...  year  quarter  month  week  day  day_of_week  \
# 7434               9.0  ...  2018        3      9    38   20            3
# 4515               0.0  ...  2018        2      6    23    9            5
# 10153              1.0  ...  2019        1      1     2    7            0
# 540                2.0  ...  2018        1      1     3   20            5
# 9183               2.0  ...  2018        4     11    47   24            5
# 11934              0.0  ...  2019        1      3    10    9            5
# 6046               4.0  ...  2018        3      8    31    2            3
# 493                0.0  ...  2018        1      1     3   19            4
# 10596              6.0  ...  2019        1      1     4   23            2
# 3701               6.0  ...  2018        2      5    19   11            4
# 5068               6.0  ...  2018        2      6    26   29            4
# 2245               1.0  ...  2018        1      3    12   21            2
# 2108               0.0  ...  2018        1      3    11   16            4
# 12823             14.0  ...  2019        2      4    15    9            1
# 1746               0.0  ...  2018        1      3     9    3            5
# 13863              2.0  ...  2019        2      5    20   17            4
# 11438              3.0  ...  2019        1      2     8   21            3
# 6521               0.0  ...  2018        3      8    33   18            5
# 1925               7.0  ...  2018        1      3    10    9            4
# 10084              0.0  ...  2019        1      1     1    4            4
#
#        day_of_year  nth_kday  next_day_delta  au_crew_mean
# 7434           263         3             1.0      4.731236
# 4515           160         2             2.0      5.935333
# 10153            7         1             1.0      4.442304
# 540             20         3             2.0      5.935333
# 9183           328         4             4.0      4.731236
# 11934           68         2             2.0      5.935333
# 6046           214         1             1.0      4.731236
# 493             19         3             1.0      5.935333
# 10596           23         4             1.0      4.442304
# 3701           131         2             1.0      5.935333
# 5068           180         5             1.0      4.731236
# 2245            80         3             1.0      4.442304
# 2108            75         3             1.0      4.731236
# 12823           99         2             3.0      5.935333
# 1746            62         1             4.0      4.731236
# 13863          137         3             1.0      5.935333
# 11438           52         3             4.0      4.442304
# 6521           230         3             2.0      5.935333
# 1925            68         2             1.0      5.935333
# 10084            4         1             1.0      4.731236
#
# [20 rows x 49 columns]

# %%
dfm_dow = dfm.groupby(['crew', 'day_of_week'])[['absences_unplanned']].mean().reset_index()
dfm_dow
# Out:
#    crew  day_of_week  absences_unplanned
# 0     A            0            5.465920
# 1     A            1            4.149959
# 2     A            2            4.059689
# 3     A            3            4.216858
# 4     B            2            4.965574
# 5     B            3            4.248157
# 6     B            4            4.867003
# 7     B            5            4.846840
# 8     C            0            6.073763
# 9     C            1            6.326429
# 10    C            4            5.574916
# 11    C            5            5.779757

# %%
dfm2 = pd.merge(dfm1, dfm_dow, left_on=['crew', 'day_of_week'], right_on=['crew', 'day_of_week'], how='left')
dfm2.rename(index=str, columns={'absences_unplanned_x': 'absences_unplanned', 'absences_unplanned_y': 'au_dow_mean'}, inplace=True)
dfm2.sample(20)
# Out:
#          workdate crew production_line  group_total_cid  lost_hours  \
# 12297  2019-03-22    B          Trim 2             70.0        40.8
# 14188  2019-05-30    A       Chassis 3             79.0        31.0
# 9367   2018-11-30    C                              6.0         0.0
# 1821   2018-03-06    C   Chassis 1 & 2             89.0        30.9
# 363    2018-01-13    C     Engine Line             62.0        60.0
# 9201   2018-11-24    C       Chassis 4             63.0        42.3
# 12960  2019-04-13    C          Trim 2             75.0        51.1
# 182    2018-01-08    A       Quality 2             47.0        30.5
# 12071  2019-03-14    B       Quality 1             46.0        30.9
# 6954   2018-09-04    C       Body Shop             24.0        28.0
# 7154   2018-09-11    A    Sunroof Deck             36.0        21.3
# 1828   2018-03-06    C        Material            102.0        60.1
# 1836   2018-03-07    A                             33.0        20.0
# 5467   2018-07-13    C      Paint Shop              2.0         0.0
# 8443   2018-10-25    A       Quality 1             61.0        20.9
# 9099   2018-11-19    C       Chassis 4             62.0         2.9
# 2523   2018-03-31    B         Final 1             70.0         3.6
# 7460   2018-09-21    B    Sunroof Deck             38.0         0.1
# 2812   2018-04-11    B         Final 1             70.0        20.0
# 12612  2019-04-02    C         Final 2             47.0        42.1
#
#        actual_hours  paa_hours  absences_unplanned  absences_late  \
# 12297         705.7        0.0                   8            1.0
# 14188         723.7       20.0                   7            1.0
# 9367           62.5        0.0                   0            0.0
# 1821          863.9        5.0                   4            1.0
# 363           587.3       10.0                   6            0.0
# 9201          597.7        0.0                   3            4.0
# 12960         697.4       10.0                   8            2.0
# 182           424.7       10.0                  10            1.0
# 12071         441.3       10.0                   2            1.0
# 6954          234.2        0.0                   3            0.0
# 7154          362.6       20.0                   0            2.0
# 1828         1030.0       10.0                  13            1.0
# 1836          327.0       10.0                   1            0.0
# 5467           24.0        0.0                   0            0.0
# 8443          602.1        0.0                   3            1.0
# 9099          585.8        0.0                   5            3.0
# 2523          686.8        0.0                   5            4.0
# 7460          373.1        0.0                   1            1.0
# 2812          662.3        0.0                   8            0.0
# 12612         458.2       10.0                  10            2.0
#
#        absences_noshow  ...  quarter  month  week  day  day_of_week  \
# 12297              4.0  ...        1      3    12   22            4
# 14188              3.0  ...        2      5    22   30            3
# 9367               0.0  ...        4     11    48   30            4
# 1821               3.0  ...        1      3    10    6            1
# 363                6.0  ...        1      1     2   13            5
# 9201               4.0  ...        4     11    47   24            5
# 12960              5.0  ...        2      4    15   13            5
# 182                3.0  ...        1      1     2    8            0
# 12071              3.0  ...        1      3    11   14            3
# 6954               2.0  ...        3      9    36    4            1
# 7154               2.0  ...        3      9    37   11            1
# 1828               6.0  ...        1      3    10    6            1
# 1836               2.0  ...        1      3    10    7            2
# 5467               0.0  ...        3      7    28   13            4
# 8443               2.0  ...        4     10    43   25            3
# 9099               0.0  ...        4     11    47   19            0
# 2523               0.0  ...        1      3    13   31            5
# 7460               0.0  ...        3      9    38   21            4
# 2812               2.0  ...        2      4    15   11            2
# 12612              4.0  ...        2      4    14    2            1
#
#        day_of_year  nth_kday  next_day_delta  au_crew_mean  au_dow_mean
# 12297           81         4             1.0      4.731236     4.867003
# 14188          150         5             0.0      4.442304     4.216858
# 9367           334         5             1.0      5.935333     5.574916
# 1821            65         1             3.0      5.935333     6.326429
# 363             13         2             3.0      5.935333     5.779757
# 9201           328         4             2.0      5.935333     5.779757
# 12960          103         2             2.0      5.935333     5.779757
# 182              8         2             1.0      4.442304     5.465920
# 12071           73         2             1.0      4.731236     4.248157
# 6954           247         1             3.0      5.935333     6.326429
# 7154           254         2             1.0      4.442304     4.149959
# 1828            65         1             3.0      5.935333     6.326429
# 1836            66         1             1.0      4.442304     4.059689
# 5467           194         2             1.0      5.935333     5.574916
# 8443           298         4             4.0      4.442304     4.216858
# 9099           323         3             1.0      5.935333     6.073763
# 2523            90         5             4.0      4.731236     4.846840
# 7460           264         3             1.0      4.731236     4.867003
# 2812           101         2             1.0      4.731236     4.965574
# 12612           92         1             3.0      5.935333     6.326429
#
# [20 rows x 50 columns]

# %%
dfm_week = dfm.groupby(['crew', 'week'])[['absences_unplanned']].mean().reset_index()
dfm_week
# Out:
#     crew  week  absences_unplanned
# 0      A     1            1.987805
# 1      A     2            3.970588
# 2      A     3            3.462185
# 3      A     4            3.915966
# 4      A     5            4.727941
# 5      A     6            4.823529
# 6      A     7            4.066176
# 7      A     8            4.154412
# 8      A     9            4.272059
# 9      A    10            4.375000
# 10     A    11            4.022059
# 11     A    12            3.750000
# 12     A    13            3.536765
# 13     A    14            4.050420
# 14     A    15            4.198529
# 15     A    16            3.691176
# 16     A    17            3.689076
# 17     A    18            4.705882
# 18     A    19            5.757353
# 19     A    20            6.382353
# 20     A    21            4.772059
# 21     A    22            5.107843
# 22     A    23            6.117647
# 23     A    24            6.205882
# 24     A    25            5.647059
# 25     A    26            4.352941
# 26     A    27            5.098039
# 27     A    28            5.617647
# 28     A    29            4.176471
# 29     A    30            4.514706
# ..   ...   ...                 ...
# 125    C    23            7.338235
# 126    C    24            6.573529
# 127    C    25            6.926471
# 128    C    26            5.970588
# 129    C    27            5.632353
# 130    C    28            7.558824
# 131    C    29            6.544118
# 132    C    30            4.485294
# 133    C    31            6.220588
# 134    C    32            6.294118
# 135    C    33            6.176471
# 136    C    34            4.676471
# 137    C    35            6.338235
# 138    C    36            6.607843
# 139    C    37            6.073529
# 140    C    38            5.014706
# 141    C    39            5.735294
# 142    C    40            5.970588
# 143    C    41            4.823529
# 144    C    42            5.397059
# 145    C    43            5.750000
# 146    C    44            5.544118
# 147    C    45            5.431373
# 148    C    46            5.666667
# 149    C    47            5.803922
# 150    C    48            6.691176
# 151    C    49            6.617647
# 152    C    50            5.602941
# 153    C    51            5.068966
# 154    C    52            0.000000
#
# [155 rows x 3 columns]

# %%
dfm3 = pd.merge(dfm2, dfm_week, left_on=['crew', 'week'], right_on=['crew', 'week'], how='left')
dfm3.rename(index=str, columns={'absences_unplanned_x': 'absences_unplanned', 'absences_unplanned_y': 'au_week_mean'}, inplace=True)
dfm3.sample(20)
# Out:
#          workdate crew production_line  group_total_cid  lost_hours  \
# 6957   2018-09-04    C       Chassis 4             60.0        51.0
# 5119   2018-06-30    C   Chassis 1 & 2             87.0        51.0
# 1203   2018-02-13    A           Rolls             26.0        20.8
# 11323  2019-02-16    C       Quality 1             52.0        50.9
# 11301  2019-02-16    B     Engine Line             60.0        83.3
# 6686   2018-08-24    C       Door Line             60.0        60.0
# 4542   2018-06-11    C       Chassis 3             71.0        50.9
# 9690   2018-12-12    A                             28.0         0.0
# 244    2018-01-10    A     Engine Line             59.0        50.0
# 11832  2019-03-06    B      Paint Shop              2.0         0.0
# 4376   2018-06-05    C         Final 1             62.0        83.2
# 4527   2018-06-11    A       Door Line             53.0        40.0
# 12012  2019-03-13    A       Chassis 3             74.0        60.0
# 4252   2018-06-01    B   Chassis 1 & 2             83.0        11.6
# 4973   2018-06-26    A        Material            107.0        90.0
# 6551   2018-08-20    C     Engine Line             61.0        61.0
# 13456  2019-05-03    C   Chassis 1 & 2             84.0        62.0
# 368    2018-01-13    C       Quality 1             57.0        10.0
# 1695   2018-03-01    B       Quality 2             38.0        30.0
# 11604  2019-02-27    A       Chassis 3             72.0        40.0
#
#        actual_hours  paa_hours  absences_unplanned  absences_late  \
# 6957          602.7       20.0                  11            1.0
# 5119          826.9       20.0                   9            1.0
# 1203          271.5        0.0                   2            1.0
# 11323         501.4       30.0                   2            1.0
# 11301         608.2       10.0                   3            5.0
# 6686          532.8        0.0                   5            0.0
# 4542          703.7       40.0                   0            1.0
# 9690          280.4        0.0                   0            0.0
# 244           596.4       20.0                   3            0.0
# 11832          20.5        0.0                   0            0.0
# 4376          627.4       50.0                  11            5.0
# 4527          501.0       10.0                   9            0.0
# 12012         722.4        3.0                   8            0.0
# 4252          818.7       10.0                   8            2.0
# 4973         1082.1       30.0                   3            0.0
# 6551          600.3       30.0                  12            1.0
# 13456         789.6       10.0                  11            2.0
# 368           544.7       25.0                   2            0.0
# 1695          363.3       10.0                   3            0.0
# 11604         706.1        0.0                  13            0.0
#
#        absences_noshow  ...  month  week  day  day_of_week  day_of_year  \
# 6957               5.0  ...      9    36    4            1          247
# 5119               5.0  ...      6    26   30            5          181
# 1203               2.0  ...      2     7   13            1           44
# 11323              5.0  ...      2     7   16            5           47
# 11301              8.0  ...      2     7   16            5           47
# 6686               6.0  ...      8    34   24            4          236
# 4542               5.0  ...      6    24   11            0          162
# 9690               0.0  ...     12    50   12            2          346
# 244                5.0  ...      1     2   10            2           10
# 11832              0.0  ...      3    10    6            2           65
# 4376               8.0  ...      6    23    5            1          156
# 4527               4.0  ...      6    24   11            0          162
# 12012              6.0  ...      3    11   13            2           72
# 4252               1.0  ...      6    22    1            4          152
# 4973               9.0  ...      6    26   26            1          177
# 6551               6.0  ...      8    34   20            0          232
# 13456              6.0  ...      5    18    3            4          123
# 368                1.0  ...      1     2   13            5           13
# 1695               3.0  ...      3     9    1            3           60
# 11604              4.0  ...      2     9   27            2           58
#
#        nth_kday  next_day_delta  au_crew_mean  au_dow_mean  au_week_mean
# 6957          1             3.0      5.935333     6.326429      6.607843
# 5119          5             2.0      5.935333     5.779757      5.970588
# 1203          2             1.0      4.442304     4.149959      4.066176
# 11323         3             2.0      5.935333     5.779757      5.455882
# 11301         3             4.0      4.731236     4.846840      4.588235
# 6686          4             1.0      5.935333     5.574916      4.676471
# 4542          2             1.0      5.935333     6.073763      6.573529
# 9690          2             1.0      4.442304     4.059689      4.602941
# 244           2             1.0      4.442304     4.059689      3.970588
# 11832         1             1.0      4.731236     4.965574      5.250000
# 4376          1             3.0      5.935333     6.326429      7.338235
# 4527          2             1.0      4.442304     5.465920      6.205882
# 12012         2             1.0      4.442304     4.059689      4.022059
# 4252          1             1.0      4.731236     4.867003      6.220588
# 4973          4             1.0      4.442304     4.149959      4.352941
# 6551          3             1.0      5.935333     6.073763      4.676471
# 13456         1             1.0      5.935333     5.574916      6.397059
# 368           2             3.0      5.935333     5.779757      4.970588
# 1695          1             1.0      4.731236     4.248157      5.375000
# 11604         4             1.0      4.442304     4.059689      4.272059
#
# [20 rows x 51 columns]

# %%
dfm_month = dfm.groupby(['crew', 'month'])[['absences_unplanned']].mean().reset_index()
dfm_month
# Out:
#    crew  month  absences_unplanned
# 0     A      1            3.791304
# 1     A      2            4.297794
# 2     A      3            3.910873
# 3     A      4            3.975045
# 4     A      5            5.420168
# 5     A      6            5.580882
# 6     A      7            4.858131
# 7     A      8            4.330065
# 8     A      9            4.670588
# 9     A     10            4.182663
# 10    A     11            4.500000
# 11    A     12            4.676471
# 12    B      1            3.682676
# 13    B      2            4.606618
# 14    B      3            4.648693
# 15    B      4            4.383302
# 16    B      5            5.906200
# 17    B      6            5.696594
# 18    B      7            5.188235
# 19    B      8            4.510836
# 20    B      9            4.387543
# 21    B     10            4.543253
# 22    B     11            4.654412
# 23    B     12            4.691244
# 24    C      1            4.852772
# 25    C      2            5.753676
# 26    C      3            5.660504
# 27    C      4            5.987132
# 28    C      5            7.196691
# 29    C      6            6.919505
# 30    C      7            6.045752
# 31    C      8            5.892734
# 32    C      9            5.863971
# 33    C     10            5.460784
# 34    C     11            5.844538
# 35    C     12            5.755760

# %%
dfm4 = pd.merge(dfm3, dfm_month, left_on=['crew', 'month'], right_on=['crew', 'month'], how='left')
dfm4.rename(index=str, columns={'absences_unplanned_x': 'absences_unplanned', 'absences_unplanned_y': 'au_month_mean'}, inplace=True)
dfm4.sample(20)
# Out:
#          workdate crew production_line  group_total_cid  lost_hours  \
# 7257   2018-09-14    B          Trim 1            116.0        62.4
# 11835  2019-03-06    B           Rolls             29.0         0.0
# 3596   2018-05-08    C        Material            115.0        82.0
# 4516   2018-06-09    C       Quality 1             50.0       103.1
# 1000   2018-02-06    A    Sunroof Deck             33.0        20.0
# 4595   2018-06-13    A       Door Line             48.0        70.0
# 6318   2018-08-11    C       Quality 1             54.0        28.0
# 12412  2019-03-26    C       Quality 2             38.0        51.6
# 4184   2018-05-30    A   Chassis 1 & 2             86.0        34.4
# 9492   2018-12-05    A     Engine Line             61.0        51.0
# 2986   2018-04-17    C       Quality 1             55.0        30.0
# 3016   2018-04-18    B         Final 1             62.0        21.8
# 2539   2018-03-31    C     Engine Line             69.0        20.0
# 1788   2018-03-05    C       Chassis 3             73.0        50.2
# 12276  2019-03-21    B       Quality 2             37.0        20.0
# 5917   2018-07-30    A       Body Shop             25.0        11.0
# 8306   2018-10-20    B      Paint Shop              2.0         0.0
# 11618  2019-02-27    B                              7.0         0.0
# 12264  2019-03-21    B                              9.0         0.0
# 12293  2019-03-22    B       Quality 2             40.0        20.0
#
#        actual_hours  paa_hours  absences_unplanned  absences_late  \
# 7257         1167.1       10.0                   5            4.0
# 11835         307.7        5.0                   2            0.0
# 3596         1100.7        0.0                  14            5.0
# 4516          483.1       50.0                   5            3.0
# 1000          333.3       10.0                   3            0.0
# 4595          472.5       20.0                   5            0.0
# 6318          518.1       10.0                   4            0.0
# 12412         378.3       10.0                   3            3.0
# 4184          840.3        0.0                  10            5.0
# 9492          611.3        0.0                   8            1.0
# 2986          551.8       26.0                   4            0.0
# 3016          614.6        0.0                   7            2.0
# 2539          626.6        0.0                   2            0.0
# 1788          722.0        0.0                   4            1.0
# 12276         359.6        0.0                   2            0.0
# 5917          226.7       10.0                   6            1.0
# 8306           25.5        0.0                   0            0.0
# 11618          75.8        0.0                   2            0.0
# 12264          93.1        0.0                   0            0.0
# 12293         395.3        0.0                   2            0.0
#
#        absences_noshow  ...  week  day  day_of_week  day_of_year  nth_kday  \
# 7257               6.0  ...    37   14            4          257         2
# 11835              0.0  ...    10    6            2           65         1
# 3596               8.0  ...    19    8            1          128         2
# 4516              10.0  ...    23    9            5          160         2
# 1000               2.0  ...     6    6            1           37         1
# 4595               7.0  ...    24   13            2          164         2
# 6318               2.0  ...    32   11            5          223         2
# 12412              5.0  ...    13   26            1           85         4
# 4184               3.0  ...    22   30            2          150         5
# 9492               5.0  ...    49    5            2          339         1
# 2986               3.0  ...    16   17            1          107         3
# 3016               2.0  ...    16   18            2          108         3
# 2539               2.0  ...    13   31            5           90         5
# 1788               5.0  ...    10    5            0           64         1
# 12276              2.0  ...    12   21            3           80         3
# 5917               1.0  ...    31   30            0          211         5
# 8306               0.0  ...    42   20            5          293         3
# 11618              0.0  ...     9   27            2           58         4
# 12264              0.0  ...    12   21            3           80         3
# 12293              2.0  ...    12   22            4           81         4
#
#        next_day_delta  au_crew_mean  au_dow_mean  au_week_mean  au_month_mean
# 7257              1.0      4.731236     4.867003      4.161765       4.387543
# 11835             1.0      4.731236     4.965574      5.250000       4.648693
# 3596              3.0      5.935333     6.326429      7.698529       7.196691
# 4516              2.0      5.935333     5.779757      7.338235       6.919505
# 1000              1.0      4.442304     4.149959      4.823529       4.297794
# 4595              1.0      4.442304     4.059689      6.205882       5.580882
# 6318              2.0      5.935333     5.779757      6.294118       5.892734
# 12412             3.0      5.935333     6.326429      5.210084       5.660504
# 4184              1.0      4.442304     4.059689      5.107843       5.420168
# 9492              1.0      4.442304     4.059689      5.191176       4.676471
# 2986              3.0      5.935333     6.326429      5.546218       5.987132
# 3016              1.0      4.731236     4.965574      4.504202       4.383302
# 2539              3.0      5.935333     5.779757      5.210084       5.660504
# 1788              1.0      5.935333     6.073763      5.345588       5.660504
# 12276             1.0      4.731236     4.248157      3.875000       4.648693
# 5917              1.0      4.442304     5.465920      4.573529       4.858131
# 8306              4.0      4.731236     4.846840      4.544118       4.543253
# 11618             1.0      4.731236     4.965574      5.375000       4.606618
# 12264             1.0      4.731236     4.248157      3.875000       4.648693
# 12293             1.0      4.731236     4.867003      3.875000       4.648693
#
# [20 rows x 52 columns]

# %%
dfm_nth = dfm.groupby(['crew', 'nth_kday', 'day_of_week'])[['absences_unplanned']].mean().reset_index()
dfm_nth
# Out:
#    crew  nth_kday  day_of_week  absences_unplanned
# 0     A         1            0            5.361345
# 1     A         1            1            4.576471
# 2     A         1            2            4.199262
# 3     A         1            3            4.125436
# 4     A         2            0            6.051471
# 5     A         2            1            4.425606
# 6     A         2            2            4.055363
# 7     A         2            3            4.197232
# 8     A         3            0            5.670588
# 9     A         3            1            3.986159
# 10    A         3            2            3.761246
# 11    A         3            3            4.131488
# 12    A         4            0            4.805430
# 13    A         4            1            3.713235
# 14    A         4            2            4.000000
# 15    A         4            3            4.054902
# 16    A         5            0            4.988235
# 17    A         5            1            3.931373
# 18    A         5            2            4.705882
# 19    A         5            3            5.176471
# 20    B         1            2            4.753731
# 21    B         1            3            4.475524
# 22    B         1            4            4.923345
# 23    B         1            5            5.023102
# 24    B         2            2            4.989619
# 25    B         2            3            4.096886
# 26    B         2            4            5.204152
# 27    B         2            5            4.743945
# 28    B         3            2            4.899654
# 29    B         3            3            4.072664
# 30    B         3            4            4.669118
# 31    B         3            5            5.069204
# 32    B         4            2            4.922794
# 33    B         4            3            4.054902
# 34    B         4            4            4.498039
# 35    B         4            5            4.765343
# 36    B         5            2            5.754902
# 37    B         5            3            5.019608
# 38    B         5            4            5.270588
# 39    B         5            5            3.986842
# 40    C         1            0            6.058824
# 41    C         1            1            6.886275
# 42    C         1            4            5.512195
# 43    C         1            5            5.947368
# 44    C         2            0            6.150735
# 45    C         2            1            6.574394
# 46    C         2            4            5.851211
# 47    C         2            5            6.408304
# 48    C         3            0            5.847059
# 49    C         3            1            6.065744
# 50    C         3            4            5.238971
# 51    C         3            5            5.927336
# 52    C         4            0            6.266968
# 53    C         4            1            5.996324
# 54    C         4            4            5.372549
# 55    C         4            5            4.960573
# 56    C         5            0            6.047059
# 57    C         5            1            5.843137
# 58    C         5            4            6.529412
# 59    C         5            5            5.148649

# %%
dfm5 = pd.merge(dfm4, dfm_nth, left_on=['crew', 'nth_kday', 'day_of_week'], right_on=['crew', 'nth_kday', 'day_of_week'], how='left')
dfm5.rename(index=str, columns={'absences_unplanned_x': 'absences_unplanned', 'absences_unplanned_y': 'au_nth_kday_mean'}, inplace=True)
dfm5.sample(20)
# Out:
#          workdate crew production_line  group_total_cid  lost_hours  \
# 1570   2018-02-26    A     Engine Line             61.0        50.8
# 9168   2018-11-21    B       Door Line             61.0        11.5
# 6223   2018-08-09    A       Body Shop             23.0         1.0
# 10271  2019-01-10    B           Rolls             29.0        10.4
# 3168   2018-04-24    A     Engine Line             61.0        50.4
# 11940  2019-03-09    C          Trim 2             71.0        61.9
# 4932   2018-06-25    A   Chassis 1 & 2             84.0        50.9
# 4348   2018-06-04    C           Rolls             25.0        40.5
# 5466   2018-07-13    C        Material            108.0       171.8
# 4252   2018-06-01    B   Chassis 1 & 2             83.0        11.6
# 7004   2018-09-06    A                             28.0         0.0
# 2099   2018-03-15    B         Final 2             50.0        11.0
# 10912  2019-02-02    C         Final 2             45.0        30.0
# 4028   2018-05-23    A          Trim 2             67.0        40.9
# 4734   2018-06-18    A         Final 2             44.0        80.0
# 1156   2018-02-12    A                             22.0         0.0
# 13477  2019-05-04    B     Engine Line             63.0        43.0
# 5119   2018-06-30    C   Chassis 1 & 2             87.0        51.0
# 6948   2018-09-04    A       Quality 2             45.0        10.0
# 9653   2018-12-10    C    Sunroof Deck             37.0        10.0
#
#        actual_hours  paa_hours  absences_unplanned  absences_late  \
# 1570          605.5        0.0                   5            1.0
# 9168          624.0        0.0                  15            3.0
# 6223          234.4        0.0                   1            1.0
# 10271         274.8        0.0                   2            1.0
# 3168          607.1       25.0                   8            1.0
# 11940         684.5        0.0                   8            2.0
# 4932          833.5       30.0                   5            1.0
# 4348          263.1       40.0                   6            1.0
# 5466         1060.3       40.0                  15            5.0
# 4252          818.7       10.0                   8            2.0
# 7004          284.5        0.0                   1            0.0
# 2099          453.2        0.0                   1            1.0
# 10912         456.4       10.0                   5            0.0
# 4028          671.1       20.0                   9            1.0
# 4734          434.6       40.0                  10            0.0
# 1156          215.2        0.0                   0            0.0
# 13477         609.2        0.0                  16            4.0
# 5119          826.9       20.0                   9            1.0
# 6948          433.6        0.0                   4            0.0
# 9653          341.9        0.0                   3            0.0
#
#        absences_noshow  ...  day  day_of_week  day_of_year  nth_kday  \
# 1570               5.0  ...   26            0           57         4
# 9168               1.0  ...   21            2          325         3
# 6223               0.0  ...    9            3          221         2
# 10271              1.0  ...   10            3           10         2
# 3168               5.0  ...   24            1          114         4
# 11940              6.0  ...    9            5           68         2
# 4932               5.0  ...   25            0          176         4
# 4348               4.0  ...    4            0          155         1
# 5466              17.0  ...   13            4          194         2
# 4252               1.0  ...    1            4          152         1
# 7004               0.0  ...    6            3          249         1
# 2099               1.0  ...   15            3           74         3
# 10912              3.0  ...    2            5           33         1
# 4028               4.0  ...   23            2          143         4
# 4734               8.0  ...   18            0          169         3
# 1156               0.0  ...   12            0           43         2
# 13477              4.0  ...    4            5          124         1
# 5119               5.0  ...   30            5          181         5
# 6948               1.0  ...    4            1          247         1
# 9653               1.0  ...   10            0          344         2
#
#        next_day_delta  au_crew_mean  au_dow_mean  au_week_mean  au_month_mean  \
# 1570              1.0      4.442304     5.465920      4.272059       4.297794
# 9168              3.0      4.731236     4.965574      6.352941       4.654412
# 6223              4.0      4.442304     4.216858      4.764706       4.330065
# 10271             1.0      4.731236     4.248157      3.205882       3.682676
# 3168              1.0      4.442304     4.149959      3.689076       3.975045
# 11940             2.0      5.935333     5.779757      5.345588       5.660504
# 4932              1.0      4.442304     5.465920      4.352941       5.580882
# 4348              1.0      5.935333     6.073763      7.338235       6.919505
# 5466              1.0      5.935333     5.574916      7.558824       6.045752
# 4252              1.0      4.731236     4.867003      6.220588       5.696594
# 7004              4.0      4.442304     4.216858      4.686275       4.670588
# 2099              1.0      4.731236     4.248157      4.529412       4.648693
# 10912             2.0      5.935333     5.779757      6.198529       5.753676
# 4028              1.0      4.442304     4.059689      4.772059       5.420168
# 4734              1.0      4.442304     5.465920      5.647059       5.580882
# 1156              1.0      4.442304     5.465920      4.066176       4.297794
# 13477             4.0      4.731236     4.846840      5.529412       5.906200
# 5119              2.0      5.935333     5.779757      5.970588       6.919505
# 6948              1.0      4.442304     4.149959      4.686275       4.670588
# 9653              1.0      5.935333     6.073763      5.602941       5.755760
#
#        au_nth_kday_mean
# 1570           4.805430
# 9168           4.899654
# 6223           4.197232
# 10271          4.096886
# 3168           3.713235
# 11940          6.408304
# 4932           4.805430
# 4348           6.058824
# 5466           5.851211
# 4252           4.923345
# 7004           4.125436
# 2099           4.072664
# 10912          5.947368
# 4028           4.000000
# 4734           5.670588
# 1156           6.051471
# 13477          5.023102
# 5119           5.148649
# 6948           4.576471
# 9653           6.150735
#
# [20 rows x 53 columns]

# %% [markdown]
# #### Holiday Calendrical Analysis

# %%
def get_holidays(df):
    years = sorted(df['year'].unique().tolist())
    all_holidays = []
    for y in years:
        holidays = calendrical.set_holidays(y, True)
        htuples = list(holidays.items())
        all_holidays += htuples
    return all_holidays

# %%
def calendrical_features(row, holidays):
    gyear = row['year']
    gmonth = row['month']
    gday = row['day']
    rdate = calendrical.gdate_to_rdate(gyear, gmonth, gday)
    holiday_rdates = [x[1] for x in holidays]
    rdate_nearest = min(holiday_rdates, key=lambda x: abs(x - rdate))
    rdate_offset = rdate - rdate_nearest
    nearest_holiday = [item for item in holidays if item[1] == rdate_nearest][0][0]
    holiday_dates = []
    for h in holidays:
        if h[0] == nearest_holiday:
            rd = calendrical.rdate_to_gdate(h[1] + rdate_offset)
            date_str = datetime.datetime(rd[0], rd[1], rd[2]).strftime("%Y-%m-%d")
            holiday_dates.append(date_str)
    return pd.Series([nearest_holiday, rdate_offset, holiday_dates], index=['holiday', 'holiday_offset', 'holiday_dates'])

# %%
holidays = get_holidays(dfm5)
holidays
# Out:
# [("New Year's Day", 736695),
#  ('MLK Day', 736709),
#  ("Valentine's Day", 736739),
#  ("President's Day", 736744),
#  ("St. Patrick's Day", 736770),
#  ('Good Friday', 736783),
#  ('Easter', 736785),
#  ('Cinco de Mayo', 736819),
#  ("Mother's Day", 736827),
#  ('Memorial Day', 736842),
#  ("Father's Day", 736862),
#  ('Independence Day', 736879),
#  ('Labor Day', 736940),
#  ('Halloween', 736695),
#  ("Veteran's Day", 737010),
#  ('Thanksgiving', 737020),
#  ('Christmas', 737053),
#  ("New Year's Day", 737060),
#  ('MLK Day', 737080),
#  ("Valentine's Day", 737104),
#  ("President's Day", 737108),
#  ("St. Patrick's Day", 737135),
#  ('Good Friday', 737168),
#  ('Easter', 737170),
#  ('Cinco de Mayo', 737184),
#  ("Mother's Day", 737191),
#  ('Memorial Day', 737206),
#  ("Father's Day", 737226),
#  ('Independence Day', 737244),
#  ('Labor Day', 737304),
#  ('Halloween', 737060),
#  ("Veteran's Day", 737374),
#  ('Thanksgiving', 737391),
#  ('Christmas', 737418)]

# %%
holiday_rdates = [x[1] for x in holidays]
holiday_rdates
# Out:
# [736695,
#  736709,
#  736739,
#  736744,
#  736770,
#  736783,
#  736785,
#  736819,
#  736827,
#  736842,
#  736862,
#  736879,
#  736940,
#  736695,
#  737010,
#  737020,
#  737053,
#  737060,
#  737080,
#  737104,
#  737108,
#  737135,
#  737168,
#  737170,
#  737184,
#  737191,
#  737206,
#  737226,
#  737244,
#  737304,
#  737060,
#  737374,
#  737391,
#  737418]

# %%
dfh = dfm5.apply(calendrical_features, holidays=holidays, axis=1)
dfh.sample(20)
# Out:
#                  holiday  holiday_offset             holiday_dates
# 3101       Cinco de Mayo             -14  [2018-04-21, 2019-04-21]
# 1749     President's Day              12  [2018-03-03, 2019-03-02]
# 5524    Independence Day              12  [2018-07-16, 2019-07-16]
# 14202       Memorial Day               3  [2018-05-31, 2019-05-30]
# 5414    Independence Day               8  [2018-07-12, 2019-07-12]
# 6392           Labor Day             -19  [2018-08-15, 2019-08-14]
# 553              MLK Day               7  [2018-01-22, 2019-01-28]
# 9028       Veteran's Day               4  [2018-11-16, 2019-11-15]
# 1193     Valentine's Day              -1  [2018-02-13, 2019-02-13]
# 13468      Cinco de Mayo              -2  [2018-05-03, 2019-05-03]
# 234              MLK Day              -6  [2018-01-09, 2019-01-15]
# 6833           Labor Day              -5  [2018-08-29, 2019-08-28]
# 3307       Cinco de Mayo              -7  [2018-04-28, 2019-04-28]
# 4027        Memorial Day              -5  [2018-05-23, 2019-05-22]
# 10478            MLK Day              -4  [2018-01-11, 2019-01-17]
# 3442       Cinco de Mayo              -2  [2018-05-03, 2019-05-03]
# 4920        Father's Day               6  [2018-06-23, 2019-06-22]
# 8105       Veteran's Day             -30  [2018-10-13, 2019-10-12]
# 3783        Mother's Day               2  [2018-05-15, 2019-05-14]
# 11887  St. Patrick's Day              -9  [2018-03-08, 2019-03-08]

# %%
dfm5 = pd.concat([dfm5, dfh], axis=1)

# %%
dfm5[['workdate', 'holiday_dates']].tail(20)
# Out:
#          workdate             holiday_dates
# 14267  2019-06-01  [2018-06-02, 2019-06-01]
# 14268  2019-06-01  [2018-06-02, 2019-06-01]
# 14269  2019-06-01  [2018-06-02, 2019-06-01]
# 14270  2019-06-01  [2018-06-02, 2019-06-01]
# 14271  2019-06-01  [2018-06-02, 2019-06-01]
# 14272  2019-06-01  [2018-06-02, 2019-06-01]
# 14273  2019-06-01  [2018-06-02, 2019-06-01]
# 14274  2019-06-01  [2018-06-02, 2019-06-01]
# 14275  2019-06-01  [2018-06-02, 2019-06-01]
# 14276  2019-06-01  [2018-06-02, 2019-06-01]
# 14277  2019-06-01  [2018-06-02, 2019-06-01]
# 14278  2019-06-01  [2018-06-02, 2019-06-01]
# 14279  2019-06-01  [2018-06-02, 2019-06-01]
# 14280  2019-06-01  [2018-06-02, 2019-06-01]
# 14281  2019-06-01  [2018-06-02, 2019-06-01]
# 14282  2019-06-01  [2018-06-02, 2019-06-01]
# 14283  2019-06-01  [2018-06-02, 2019-06-01]
# 14284  2019-06-01  [2018-06-02, 2019-06-01]
# 14285  2019-06-01  [2018-06-02, 2019-06-01]
# 14286  2019-06-01  [2018-06-02, 2019-06-01]

# %%
dfm_nth = dfm.groupby(['crew', 'nth_kday', 'day_of_week'])[['absences_unplanned']].mean().reset_index()
dfm_nth
# Out:
#    crew  nth_kday  day_of_week  absences_unplanned
# 0     A         1            0            5.361345
# 1     A         1            1            4.576471
# 2     A         1            2            4.199262
# 3     A         1            3            4.125436
# 4     A         2            0            6.051471
# 5     A         2            1            4.425606
# 6     A         2            2            4.055363
# 7     A         2            3            4.197232
# 8     A         3            0            5.670588
# 9     A         3            1            3.986159
# 10    A         3            2            3.761246
# 11    A         3            3            4.131488
# 12    A         4            0            4.805430
# 13    A         4            1            3.713235
# 14    A         4            2            4.000000
# 15    A         4            3            4.054902
# 16    A         5            0            4.988235
# 17    A         5            1            3.931373
# 18    A         5            2            4.705882
# 19    A         5            3            5.176471
# 20    B         1            2            4.753731
# 21    B         1            3            4.475524
# 22    B         1            4            4.923345
# 23    B         1            5            5.023102
# 24    B         2            2            4.989619
# 25    B         2            3            4.096886
# 26    B         2            4            5.204152
# 27    B         2            5            4.743945
# 28    B         3            2            4.899654
# 29    B         3            3            4.072664
# 30    B         3            4            4.669118
# 31    B         3            5            5.069204
# 32    B         4            2            4.922794
# 33    B         4            3            4.054902
# 34    B         4            4            4.498039
# 35    B         4            5            4.765343
# 36    B         5            2            5.754902
# 37    B         5            3            5.019608
# 38    B         5            4            5.270588
# 39    B         5            5            3.986842
# 40    C         1            0            6.058824
# 41    C         1            1            6.886275
# 42    C         1            4            5.512195
# 43    C         1            5            5.947368
# 44    C         2            0            6.150735
# 45    C         2            1            6.574394
# 46    C         2            4            5.851211
# 47    C         2            5            6.408304
# 48    C         3            0            5.847059
# 49    C         3            1            6.065744
# 50    C         3            4            5.238971
# 51    C         3            5            5.927336
# 52    C         4            0            6.266968
# 53    C         4            1            5.996324
# 54    C         4            4            5.372549
# 55    C         4            5            4.960573
# 56    C         5            0            6.047059
# 57    C         5            1            5.843137
# 58    C         5            4            6.529412
# 59    C         5            5            5.148649

# %%
dfm5['holiday_dates'].iloc[1]
# Out:
# ['2018-01-02', '2019-01-02']

# %%
def holiday_mean(row, df):
    holiday_dates = row['holiday_dates']
    holiday_mean = df['absences_unplanned'][df['workdate'].isin(holiday_dates)].mean()
    return holiday_mean

# %%
dfm5['au_holiday_mean'] = dfm5.apply(holiday_mean, df=dfm5, axis=1)
dfm5[['workdate', 'au_holiday_mean']].tail(20)
# Out:
#          workdate  au_holiday_mean
# 14267  2019-06-01         7.676471
# 14268  2019-06-01         7.676471
# 14269  2019-06-01         7.676471
# 14270  2019-06-01         7.676471
# 14271  2019-06-01         7.676471
# 14272  2019-06-01         7.676471
# 14273  2019-06-01         7.676471
# 14274  2019-06-01         7.676471
# 14275  2019-06-01         7.676471
# 14276  2019-06-01         7.676471
# 14277  2019-06-01         7.676471
# 14278  2019-06-01         7.676471
# 14279  2019-06-01         7.676471
# 14280  2019-06-01         7.676471
# 14281  2019-06-01         7.676471
# 14282  2019-06-01         7.676471
# 14283  2019-06-01         7.676471
# 14284  2019-06-01         7.676471
# 14285  2019-06-01         7.676471
# 14286  2019-06-01         7.676471

# %%
dfm5.columns
# Out:
# Index(['workdate', 'crew', 'production_line', 'group_total_cid', 'lost_hours',
#        'actual_hours', 'paa_hours', 'absences_unplanned', 'absences_late',
#        'absences_noshow', 'absences_any', 'mean_absence_pct',
#        'mean_experience', 'absences_planned', 'home_canvasses',
#        'absences_fmla', 'peia_count', 'tpt_count', 'streak_1', 'streak_2',
#        'streak_3', 'streak_4_plus', 'cluster', 'group_total', 'tpt_unplanned',
#        'tpt_extra', 'absences_unplanned_rolling_sum_5',
#        'absences_unplanned_rolling_median_5',
#        'absences_unplanned_rolling_sum_12',
#        'absences_unplanned_rolling_median_12',
#        'absences_unplanned_rolling_sum_20',
#        'absences_unplanned_rolling_median_20', 'actual_hours_rolling_mean_20',
#        'actual_hours_rolling_median_20', 'lost_hours_rolling_mean_20',
#        'lost_hours_rolling_median_20', 'kp_residual_5', 'kp_residual_12',
#        'kp_residual_20', 'year', 'quarter', 'month', 'week', 'day',
#        'day_of_week', 'day_of_year', 'nth_kday', 'next_day_delta',
#        'au_crew_mean', 'au_dow_mean', 'au_week_mean', 'au_month_mean',
#        'au_nth_kday_mean', 'holiday_dates', 'au_holiday_mean', 'holiday',
#        'holiday_offset', 'holiday_dates'],
#       dtype='object')

# %%
dfm5['au_dow_pct'] = round(100 * (dfm5['au_dow_mean'] / dfm5['au_crew_mean'] - 1), 0).astype(int)
dfm5['au_week_pct'] = round(100 * (dfm5['au_week_mean'] / dfm5['au_crew_mean'] - 1), 0).astype(int)
dfm5['au_month_pct'] = round(100 * (dfm5['au_month_mean'] / dfm5['au_crew_mean'] - 1), 0).astype(int)
dfm5['au_nth_kday_pct'] = round(100 * (dfm5['au_nth_kday_mean'] / dfm5['au_crew_mean'] - 1), 0).astype(int)   
dfm5['au_holiday_pct'] = round(100 * (dfm5['au_holiday_mean'] / dfm5['au_crew_mean'] - 1), 0).astype(int)

# %%
dfm5['workdate_dt'] = pd.to_datetime(dfm5['workdate'])
dfm5['day_name'] = dfm5['workdate_dt'].dt.day_name()
dfm5['month_name'] = dfm5['workdate_dt'].dt.month_name()

# %%
dfm5.sample(20)
# Out:
#          workdate crew production_line  group_total_cid  lost_hours  \
# 13581  2019-05-08    A         Final 2             44.0        70.0
# 13445  2019-05-03    B         Final 2             43.0        41.2
# 3608   2018-05-09    A       Chassis 4             62.0        42.5
# 8771   2018-11-05    C          Trim 2             74.0        53.6
# 2524   2018-03-31    B         Final 2             48.0        20.1
# 13329  2019-04-29    C       Quality 1             48.0        41.8
# 7588   2018-09-26    A     Engine Line             64.0        30.0
# 12650  2019-04-03    B       Quality 2             38.0        11.0
# 4641   2018-06-14    B                             21.0        20.0
# 9604   2018-12-08    B          Trim 2             72.0        51.1
# 13409  2019-05-02    A     Engine Line             64.0        40.3
# 12594  2019-04-02    A         Final 1             64.0        71.0
# 821    2018-01-31    A       Door Line             54.0        40.9
# 10630  2019-01-24    A          Trim 1            107.0       201.4
# 8582   2018-10-30    A    Sunroof Deck             37.0        30.0
# 6424   2018-08-15    B          Trim 1            111.0        32.6
# 284    2018-01-11    A       Quality 2             44.0        30.0
# 5738   2018-07-23    C        Material            107.0       181.0
# 7132   2018-09-10    C        Material            119.0       111.0
# 11473  2019-02-22    B         Final 2             47.0         1.6
#
#        actual_hours  paa_hours  absences_unplanned  absences_late  \
# 13581         443.5       50.0                   6            0.0
# 13445         429.8        8.0                   5            2.0
# 3608          595.1        5.0                   6            3.0
# 8771          691.5       20.0                   5            4.0
# 2524          475.3        0.0                   3            1.0
# 13329         487.2       40.0                   3            3.0
# 7588          614.8        0.0                   2            0.0
# 12650         369.9        0.0                   5            1.0
# 4641          226.9        0.0                   2            0.0
# 9604          712.1       10.0                   6            1.0
# 13409         606.0        0.0                   5            2.0
# 12594         581.7        0.0                   7            1.0
# 821           540.0        0.0                   1            1.0
# 10630        1071.8       50.0                  10            2.0
# 8582          369.5       10.0                   4            0.0
# 6424         1088.3       30.0                   2            4.0
# 284           417.0        5.0                   3            0.0
# 5738         1064.0       70.0                   8            1.0
# 7132         1087.3       20.0                  13            1.0
# 11473         452.8        0.0                   1            2.0
#
#        absences_noshow  ...             holiday_dates  au_holiday_mean  \
# 13581              7.0  ...  [2018-05-08, 2019-05-08]         6.117647
# 13445              4.0  ...  [2018-05-03, 2019-05-03]         5.411765
# 3608               4.0  ...  [2018-05-09, 2019-05-09]         5.367647
# 8771               5.0  ...  [2018-11-05, 2019-11-04]         4.323529
# 2524               2.0  ...  [2018-03-31, 2019-04-20]         5.426471
# 13329              4.0  ...  [2018-04-29, 2019-04-29]         6.000000
# 7588               3.0  ...  [2018-09-26, 2019-09-25]         3.735294
# 12650              1.0  ...  [2018-03-14, 2019-04-03]         4.382353
# 4641               2.0  ...  [2018-06-14, 2019-06-13]         6.147059
# 9604               5.0  ...  [2018-12-08, 2019-12-14]         5.764706
# 13409              4.0  ...  [2018-05-02, 2019-05-02]         4.735294
# 12594              7.0  ...  [2018-04-02, 2019-04-02]         6.147059
# 821                4.0  ...  [2018-01-31, 2019-01-31]         5.500000
# 10630             20.0  ...  [2018-01-18, 2019-01-24]         3.250000
# 8582               3.0  ...  [2018-10-30, 2019-10-29]         4.382353
# 6424               3.0  ...  [2018-08-15, 2019-08-14]         3.735294
# 284                3.0  ...  [2018-01-11, 2019-01-17]         3.205882
# 5738              18.0  ...  [2018-07-23, 2019-07-23]         5.205882
# 7132              11.0  ...  [2018-09-10, 2019-09-09]         6.823529
# 11473              0.0  ...  [2018-02-23, 2019-02-22]         4.352941
#
#        au_dow_pct  au_week_pct  au_month_pct  au_nth_kday_pct  au_holiday_pct  \
# 13581          -9           30            22               -9              38
# 13445           3           17            25                4              14
# 3608           -9           30            22               -9              21
# 8771            2           -8            -2                2             -27
# 2524            2          -10            -2              -16              15
# 13329           2            8             1                2               1
# 7588           -9           -4             5              -10             -16
# 12650           5          -12            -7                0              -7
# 4641          -10           22            20              -13              30
# 9604            2            9            -1                0              22
# 13409          -5            6            22               -7               7
# 12594          -7           -9           -11                3              38
# 821            -9            6           -15                6              24
# 10630          -5          -12           -15               -9             -27
# 8582           -7           -4            -6              -12              -1
# 6424            5           -5            -5                4             -21
# 284            -5          -11           -15               -6             -28
# 5738            2          -24             2                6             -12
# 7132            2            2            -1                4              15
# 11473           3           -7            -3               -5              -8
#
#        workdate_dt   day_name  month_name
# 13581   2019-05-08  Wednesday         May
# 13445   2019-05-03     Friday         May
# 3608    2018-05-09  Wednesday         May
# 8771    2018-11-05     Monday    November
# 2524    2018-03-31   Saturday       March
# 13329   2019-04-29     Monday       April
# 7588    2018-09-26  Wednesday   September
# 12650   2019-04-03  Wednesday       April
# 4641    2018-06-14   Thursday        June
# 9604    2018-12-08   Saturday    December
# 13409   2019-05-02   Thursday         May
# 12594   2019-04-02    Tuesday       April
# 821     2018-01-31  Wednesday     January
# 10630   2019-01-24   Thursday     January
# 8582    2018-10-30    Tuesday     October
# 6424    2018-08-15  Wednesday      August
# 284     2018-01-11   Thursday     January
# 5738    2018-07-23     Monday        July
# 7132    2018-09-10     Monday   September
# 11473   2019-02-22     Friday    February
#
# [20 rows x 65 columns]

# %%
dfm5['feature1'] = dfm5['day_name'] + ': ' + dfm5['au_dow_pct'].astype(str) + '%' 
dfm5['feature1'].sample(20)
# Out:
# 13143      Tuesday: -7%
# 9149     Wednesday: -9%
# 12584        Monday: 2%
# 4835      Thursday: -5%
# 11218     Wednesday: 5%
# 6920      Saturday: -3%
# 4908       Saturday: 2%
# 76        Thursday: -5%
# 794        Tuesday: -7%
# 1258      Thursday: -5%
# 475      Thursday: -10%
# 8499        Friday: -6%
# 6887        Friday: -6%
# 10713     Saturday: -3%
# 1545       Saturday: 2%
# 1009        Tuesday: 7%
# 3775       Tuesday: -7%
# 7253         Friday: 3%
# 13882      Saturday: 2%
# 3484         Friday: 3%
# Name: feature1, dtype: object

# %%
dfm5['feature2'] = 'Week ' + dfm5['week'].astype(str) + ': ' + dfm5['au_week_pct'].astype(str) + '%'
dfm5['feature2'].sample(20)
# Out:
# 4070      Week 21: 26%
# 2730      Week 15: -5%
# 11588       Week 9: 8%
# 6713       Week 34: 0%
# 12557     Week 14: -9%
# 8402     Week 43: -15%
# 10981      Week 6: 18%
# 13469      Week 18: 8%
# 4774      Week 25: 27%
# 1598       Week 9: -4%
# 10522      Week 3: -8%
# 5840      Week 30: 10%
# 4902      Week 25: 14%
# 3695      Week 19: 30%
# 1989       Week 11: 0%
# 2076      Week 11: -9%
# 12708     Week 14: 11%
# 6406       Week 33: 6%
# 7252     Week 37: -12%
# 10835       Week 5: 6%
# Name: feature2, dtype: object

# %%
dfm5['feature3'] = dfm5['month_name'] + ': ' + dfm5['au_month_pct'].astype(str) + '%'
dfm5['feature3'].sample(20)
# Out:
# 9645      December: -3%
# 7823       October: -6%
# 12356       March: -12%
# 12240        March: -2%
# 13221        April: -7%
# 2562        April: -11%
# 5676           July: 2%
# 2541         March: -5%
# 8512       October: -4%
# 3658           May: 25%
# 2055        March: -12%
# 5340           July: 9%
# 4164           May: 22%
# 9892      December: -3%
# 6656        August: -5%
# 7648     September: -7%
# 2839         April: -7%
# 8216       October: -4%
# 441       January: -22%
# 1419      February: -3%
# Name: feature3, dtype: object

# %%
dfm5['feature4'] = dfm5['nth_kday'].astype(str) + ' ' + dfm5['day_name'] +  ': ' + dfm5['au_nth_kday_pct'].astype(str) + '%'
dfm5['feature4'] = dfm5['feature4'].str.replace('^1', '1st', regex=True)
dfm5['feature4'] = dfm5['feature4'].str.replace('^2', '2nd', regex=True)
dfm5['feature4'] = dfm5['feature4'].str.replace('^3', '3rd', regex=True)
dfm5['feature4'] = dfm5['feature4'].str.replace('^4', '4th', regex=True)
dfm5['feature4'] = dfm5['feature4'].str.replace('^5', '5th', regex=True)
dfm5['feature4'].sample(20)
# Out:
# 164        1st Saturday: 0%
# 10921       1st Monday: 21%
# 10262    2nd Thursday: -13%
# 11482       4th Friday: -9%
# 3220      4th Wednesday: 4%
# 1925        2nd Friday: -1%
# 6029      1st Thursday: -7%
# 1978        2nd Monday: 36%
# 1675      1st Thursday: -7%
# 9933      3rd Thursday: -7%
# 10062     1st Thursday: -7%
# 4469        2nd Friday: 10%
# 4625      2nd Thursday: -6%
# 4486        2nd Friday: -1%
# 13700      2nd Saturday: 8%
# 210         2nd Tuesday: 0%
# 1857      1st Wednesday: 0%
# 4894        4th Friday: -9%
# 102          1st Friday: 4%
# 6033      1st Thursday: -7%
# Name: feature4, dtype: object

# %%
dfm5['holiday_plus_minus'] = dfm5['holiday_offset'].apply(lambda x: 'after' if x > 0 else 'before')
dfm5.loc[dfm5['holiday_offset'] == 0, 'holiday_plus_minus'] = 'it\'s'
dfm5['feature5'] = abs(dfm5['holiday_offset']).astype(str) + ' days ' + dfm5['holiday_plus_minus'] + ' ' \
                   + dfm5['holiday'] + ': ' + dfm5['au_holiday_pct'].astype(str) + '%'
# Out:
# 2309     5 days after St. Patrick's Day: -14%
# 6638           11 days before Labor Day: -11%
# 4156           1 days after Memorial Day: 43%
# 2113      1 days before St. Patrick's Day: 0%
# 6346            21 days before Labor Day: 19%
# 11225       1 days before Valentine's Day: 5%
# 5576      14 days after Independence Day: -9%
# 13118           1 days after Good Friday: -9%
# 9044         5 days after Veteran's Day: -12%
# 7062             4 days after Labor Day: -10%
# 11729      12 days after President's Day: -4%
# 7983       34 days before Veteran's Day: -22%
# 12006    5 days before St. Patrick's Day: -8%
# 4107           3 days before Memorial Day: 5%
# 9064         5 days after Veteran's Day: -30%
# 11971    6 days before St. Patrick's Day: 15%
# 2968                16 days after Easter: 41%
# 5667     16 days after Independence Day: -15%
# 13407         3 days before Cinco de Mayo: 7%
# 12696         14 days before Good Friday: -5%
# Name: feature5, dtype: object

# %%
dfm5['feature5'].sample(20)
# Out:
# 7976         34 days before Veteran's Day: -22%
# 2764                   9 days after Easter: 18%
# 9217             4 days after Thanksgiving: 52%
# 12470     11 days after St. Patrick's Day: -24%
# 11340          0 days it's President's Day: 29%
# 14146             1 days after Memorial Day: 7%
# 1828     11 days before St. Patrick's Day: -19%
# 11003        8 days before Valentine's Day: 37%
# 10015       3 days before New Year's Day: -100%
# 4830             4 days after Father's Day: -3%
# 9676             14 days before Christmas: -20%
# 6596              12 days before Labor Day: -6%
# 4885            5 days after Father's Day: -10%
# 7417               17 days after Labor Day: -5%
# 12720          14 days before Good Friday: -24%
# 7607              23 days after Labor Day: -21%
# 1739         12 days after President's Day: 21%
# 11295         2 days after Valentine's Day: -7%
# 872        13 days before Valentine's Day: -10%
# 5216         1 days after Independence Day: 48%
# Name: feature5, dtype: object

# %%
def create_calendrical_stats(dfm):
    dfm_mean = dfm.groupby(['crew'])[['absences_unplanned']].mean().reset_index()
    dfm1 = pd.merge(dfm, dfm_mean, left_on=['crew'], right_on=['crew'], how='left')
    dfm1.rename(index=str, columns={'absences_unplanned_x': 'absences_unplanned', 'absences_unplanned_y': 'au_crew_mean'}, inplace=True)
    dfm_dow = dfm.groupby(['crew', 'day_of_week'])[['absences_unplanned']].mean().reset_index()
    dfm2 = pd.merge(dfm1, dfm_dow, left_on=['crew', 'day_of_week'], right_on=['crew', 'day_of_week'], how='left')
    dfm2.rename(index=str, columns={'absences_unplanned_x': 'absences_unplanned', 'absences_unplanned_y': 'au_dow_mean'}, inplace=True)
    dfm_week = dfm.groupby(['crew', 'week'])[['absences_unplanned']].mean().reset_index()
    dfm3 = pd.merge(dfm2, dfm_week, left_on=['crew', 'week'], right_on=['crew', 'week'], how='left')
    dfm3.rename(index=str, columns={'absences_unplanned_x': 'absences_unplanned', 'absences_unplanned_y': 'au_week_mean'}, inplace=True)
    dfm_month = dfm.groupby(['crew', 'month'])[['absences_unplanned']].mean().reset_index()
    dfm4 = pd.merge(dfm3, dfm_month, left_on=['crew', 'month'], right_on=['crew', 'month'], how='left')
    dfm4.rename(index=str, columns={'absences_unplanned_x': 'absences_unplanned', 'absences_unplanned_y': 'au_month_mean'}, inplace=True)
    dfm_nth = dfm.groupby(['crew', 'nth_kday', 'day_of_week'])[['absences_unplanned']].mean().reset_index()
    dfm5 = pd.merge(dfm4, dfm_nth, left_on=['crew', 'nth_kday', 'day_of_week'], right_on=['crew', 'nth_kday', 'day_of_week'], how='left')
    dfm5.rename(index=str, columns={'absences_unplanned_x': 'absences_unplanned', 'absences_unplanned_y': 'au_nth_kday_mean'}, inplace=True)
    holidays = get_holidays(dfm5)
    dfh = dfm5.apply(calendrical_features, holidays=holidays, axis=1)
    dfm5 = pd.concat([dfm5, dfh], axis=1)
    dfm5['au_holiday_mean'] = dfm5.apply(holiday_mean, df=dfm5, axis=1)
    dfm5['au_dow_pct'] = round(100 * (dfm5['au_dow_mean'] / dfm5['au_crew_mean'] - 1), 0).astype(int)
    dfm5['au_week_pct'] = round(100 * (dfm5['au_week_mean'] / dfm5['au_crew_mean'] - 1), 0).astype(int)
    dfm5['au_month_pct'] = round(100 * (dfm5['au_month_mean'] / dfm5['au_crew_mean'] - 1), 0).astype(int)
    dfm5['au_nth_kday_pct'] = round(100 * (dfm5['au_nth_kday_mean'] / dfm5['au_crew_mean'] - 1), 0).astype(int) 
    dfm5['au_holiday_pct'] = round(100 * (dfm5['au_holiday_mean'] / dfm5['au_crew_mean'] - 1), 0).astype(int)
    dfm5['workdate_dt'] = pd.to_datetime(dfm5['workdate'])
    dfm5['day_name'] = dfm5['workdate_dt'].dt.day_name()
    dfm5['month_name'] = dfm5['workdate_dt'].dt.month_name()
    dfm5['feature1'] = dfm5['day_name'] + ': ' + dfm5['au_dow_pct'].astype(str) + '%'
    dfm5['feature2'] = 'Week ' + dfm5['week'].astype(str) + ': ' + dfm5['au_week_pct'].astype(str) + '%'
    dfm5['feature3'] = dfm5['month_name'] + ': ' + dfm5['au_month_pct'].astype(str) + '%'
    dfm5['feature4'] = dfm5['nth_kday'].astype(str) + ' ' + dfm5['day_name'] +  ': ' + dfm5['au_nth_kday_pct'].astype(str) + '%'
    dfm5['feature4'] = dfm5['feature4'].str.replace('^1', '1st', regex=True)
    dfm5['feature4'] = dfm5['feature4'].str.replace('^2', '2nd', regex=True)
    dfm5['feature4'] = dfm5['feature4'].str.replace('^3', '3rd', regex=True)
    dfm5['feature4'] = dfm5['feature4'].str.replace('^4', '4th', regex=True)
    dfm5['feature4'] = dfm5['feature4'].str.replace('^5', '5th', regex=True)
    dfm5['holiday_plus_minus'] = dfm5['holiday_offset'].apply(lambda x: 'after' if x > 0 else 'before')
    dfm5.loc[dfm5['holiday_offset'] == 0, 'holiday_plus_minus'] = 'it\'s'
    dfm5['feature5'] = abs(dfm5['holiday_offset']).astype(str) + ' days ' + dfm5['holiday_plus_minus'] + ' ' \
                       + dfm5['holiday'] + ': ' + dfm5['au_holiday_pct'].astype(str) + '%'
    drop_cols = ['workdate_dt', 'holiday_plus_minus']
    dfm5.drop(columns=drop_cols, inplace=True)
    return dfm5

# %%
dfm_out = create_calendrical_stats(dfm)

# %%
dfm_out[['workdate', 'feature1', 'feature2', 'feature3', 'feature4', 'feature5']].sample(50)
# Out:
#          workdate        feature1       feature2        feature3  \
# 4318   2018-06-04     Monday: 23%   Week 23: 38%       June: 26%
# 7399   2018-09-19   Wednesday: 5%   Week 38: 11%  September: -7%
# 7117   2018-09-10     Monday: 23%   Week 37: 14%   September: 5%
# 1538   2018-02-24    Saturday: 2%    Week 8: -7%   February: -3%
# 12683  2019-04-04  Thursday: -10%  Week 14: -12%      April: -7%
# 12370  2019-03-25      Monday: 2%  Week 13: -12%      March: -5%
# 3754   2018-05-14     Monday: 23%   Week 20: 44%        May: 22%
# 561    2018-01-22      Monday: 2%   Week 4: -24%   January: -18%
# 2314   2018-03-23      Friday: 3%  Week 12: -18%      March: -2%
# 8610   2018-10-31  Wednesday: -9%   Week 44: -4%    October: -6%
# 5130   2018-06-30   Saturday: -3%    Week 26: 1%       June: 17%
# 5200   2018-07-03     Tuesday: 7%   Week 27: -5%        July: 2%
# 3265   2018-04-27      Friday: 3%   Week 17: -9%      April: -7%
# 1649   2018-02-28   Wednesday: 5%    Week 9: 14%   February: -3%
# 7066   2018-09-07     Friday: -6%   Week 36: 11%  September: -1%
# 14204  2019-05-30  Thursday: -10%   Week 22: 31%        May: 25%
# 5961   2018-07-31    Tuesday: -7%    Week 31: 3%        July: 9%
# 796    2018-01-30    Tuesday: -7%     Week 5: 6%   January: -15%
# 1169   2018-02-12     Monday: 23%    Week 7: -8%   February: -3%
# 3809   2018-05-16  Wednesday: -9%   Week 20: 44%        May: 22%
# 8790   2018-11-07   Wednesday: 5%  Week 45: -20%   November: -2%
# 1720   2018-03-02     Friday: -6%     Week 9: 8%      March: -5%
# 6391   2018-08-14     Tuesday: 7%    Week 33: 4%     August: -1%
# 8438   2018-10-25   Thursday: -5%  Week 43: -15%    October: -6%
# 9123   2018-11-20    Tuesday: -7%    Week 47: 0%    November: 1%
# 6839   2018-08-30   Thursday: -5%  Week 35: -15%     August: -3%
# 10889  2019-02-02    Saturday: 2%     Week 5: 3%   February: -3%
# 5070   2018-06-29      Friday: 3%   Week 26: -1%       June: 20%
# 7838   2018-10-04  Thursday: -10%   Week 40: -6%    October: -4%
# 10637  2019-01-24  Thursday: -10%   Week 4: -18%   January: -22%
# 2713   2018-04-07   Saturday: -3%   Week 14: 11%       April: 1%
# 13439  2019-05-03      Friday: 3%   Week 18: 17%        May: 25%
# 337    2018-01-12     Friday: -6%   Week 2: -16%   January: -18%
# 10692  2019-01-26    Saturday: 2%   Week 4: -18%   January: -22%
# 5798   2018-07-25   Wednesday: 5%   Week 30: 10%       July: 10%
# 5889   2018-07-28    Saturday: 2%   Week 30: 10%       July: 10%
# 2117   2018-03-16      Friday: 3%   Week 11: -4%      March: -2%
# 288    2018-01-11   Thursday: -5%   Week 2: -11%   January: -15%
# 440    2018-01-17   Wednesday: 5%    Week 3: -8%   January: -22%
# 2827   2018-04-12   Thursday: -5%   Week 15: -5%     April: -11%
# 6782   2018-08-28    Tuesday: -7%  Week 35: -15%     August: -3%
# 1842   2018-03-07  Wednesday: -9%   Week 10: -2%     March: -12%
# 9318   2018-11-29   Thursday: -5%   Week 48: 20%    November: 1%
# 1314   2018-02-16     Friday: -6%    Week 7: -8%   February: -3%
# 9024   2018-11-16      Friday: 3%  Week 46: -37%   November: -2%
# 8109   2018-10-13   Saturday: -3%  Week 41: -19%    October: -8%
# 2473   2018-03-28   Wednesday: 5%  Week 13: -10%      March: -2%
# 7924   2018-10-08     Monday: 23%   Week 41: -9%    October: -6%
# 14120  2019-05-28    Tuesday: -7%   Week 22: 15%        May: 22%
# 12587  2019-04-02    Tuesday: -7%   Week 14: -9%     April: -11%
#
#                   feature4                               feature5
# 4318       1st Monday: 21%         7 days after Memorial Day: 58%
# 7399     3rd Wednesday: 4%           16 days after Labor Day: -6%
# 7117       2nd Monday: 36%            7 days after Labor Day: 54%
# 1538      4th Saturday: 1%      5 days after President's Day: -1%
# 12683    1st Thursday: -5%       15 days before Good Friday: -19%
# 12370       4th Monday: 6%     8 days after St. Patrick's Day: 2%
# 3754       2nd Monday: 36%         1 days after Mother's Day: 66%
# 561         4th Monday: 6%               7 days after MLK Day: 6%
# 2314       4th Friday: -5%    6 days after St. Patrick's Day: -5%
# 8610     5th Wednesday: 6%      12 days before Veteran's Day: 19%
# 5130    5th Saturday: -13%    4 days before Independence Day: -1%
# 5200      1st Tuesday: 16%   1 days before Independence Day: -13%
# 3265       4th Friday: -5%       8 days before Cinco de Mayo: 11%
# 1649     4th Wednesday: 4%       9 days after President's Day: 7%
# 7066       1st Friday: -7%           4 days after Labor Day: -10%
# 14204     5th Thursday: 6%         3 days after Memorial Day: 17%
# 5961     5th Tuesday: -12%    27 days after Independence Day: 10%
# 796      5th Tuesday: -12%             15 days after MLK Day: -4%
# 1169       2nd Monday: 36%     2 days before Valentine's Day: 24%
# 3809   3rd Wednesday: -15%         3 days after Mother's Day: 29%
# 8790     1st Wednesday: 0%      5 days before Veteran's Day: -29%
# 1720       1st Friday: -7%      11 days after President's Day: 2%
# 6391      2nd Tuesday: 11%          20 days before Labor Day: -5%
# 8438     4th Thursday: -9%     18 days before Veteran's Day: -21%
# 9123     3rd Tuesday: -10%        2 days before Thanksgiving: 13%
# 6839     5th Thursday: 17%          4 days before Labor Day: -26%
# 10889     1st Saturday: 6%            12 days after MLK Day: -17%
# 5070       5th Friday: 11%     5 days before Independence Day: 3%
# 7838     1st Thursday: -5%          31 days after Labor Day: -21%
# 10637   4th Thursday: -14%             3 days after MLK Day: -31%
# 2713      1st Saturday: 0%              6 days after Easter: -17%
# 13439       1st Friday: 4%       2 days before Cinco de Mayo: 14%
# 337        2nd Friday: -1%            3 days before MLK Day: -33%
# 10692     4th Saturday: 1%              5 days after MLK Day: -7%
# 5798     4th Wednesday: 4%    21 days after Independence Day: -7%
# 5889      4th Saturday: 1%    24 days after Independence Day: 14%
# 2117       3rd Friday: -1%    1 days before St. Patrick's Day: 0%
# 288      2nd Thursday: -6%            4 days before MLK Day: -28%
# 440      3rd Wednesday: 4%              2 days after MLK Day: -1%
# 2827     2nd Thursday: -6%             11 days after Easter: -11%
# 6782     4th Tuesday: -16%           6 days before Labor Day: 10%
# 1842    1st Wednesday: -5%  10 days before St. Patrick's Day: 12%
# 9318     5th Thursday: 17%         7 days after Thanksgiving: 19%
# 1314      3rd Friday: -12%     2 days after Valentine's Day: -26%
# 9024       3rd Friday: -1%        4 days after Veteran's Day: -9%
# 8109      2nd Saturday: 8%     30 days before Veteran's Day: -26%
# 2473     4th Wednesday: 4%        2 days before Good Friday: -38%
# 7924       2nd Monday: 36%           35 days after Labor Day: 21%
# 14120    4th Tuesday: -16%         1 days after Memorial Day: 43%
# 12587      1st Tuesday: 3%   16 days after St. Patrick's Day: 38%

# %%
holidays_2018 = calendrical.set_holidays(2018, True)
holidays_2018

# %%
tuples_2018 = list(holidays_2018.items())
tuples_2018

# %%
holidays_2019 = calendrical.set_holidays(2019, True)
holidays_2019

# %%
tuples_2019 = list(holidays_2019.items())
tuples_2019

# %%
all_tuples = tuples_2018 + tuples_2019
all_tuples

# %%
test_rdate = calendrical.gdate_to_rdate(2019, 5, 20)
test_rdate

# %%
ph = calendrical.previous_holiday(test_rdate, holidays_2019)
ph

# %%
htuple = [item for item in all_tuples if item[1] == ph][0]
htuple[0]

# %%
nh = calendrical.next_holiday(test_rdate, holidays_2019)
nh

# %%
htuple = [item for item in all_tuples if item[1] == nh][0]
htuple[0]

# %%
test_gdate = calendrical.rdate_to_gdate(test_rdate)
test_gdate

# %%
date_str = datetime.datetime(test_gdate[0], test_gdate[1], test_gdate[2]).strftime("%Y-%m-%d")
date_str

# %% [markdown]
# ### End of Notebook
